# %%
import os
import subprocess
import torch
from transformers import GPT2Tokenizer
import sys
nanoGPT_dir = "C:/Users/Zheng/OneDrive - UW-Madison/PhD project/Coursework/CS839/hw1/nanoGPT-master"
sys.path.append(nanoGPT_dir)
os.chdir(nanoGPT_dir)
from model import GPTConfig, GPT

# %%
# Prepare the path for the script you want to run
prepare_script = os.path.join("data", "shakespeare_char", "prepare.py")

# Run the script using os.system
os.system(f'python "{prepare_script}"')

# Run scripts
train_script = os.path.join("train.py")
config_path = os.path.join("config", "train_shakespeare_char.py")
command = f'python "{train_script}" "{config_path}" --device=cpu --compile=False --eval_iters=20 --log_interval=1 --block_size=64 --batch_size=12 --n_layer=4 --n_head=4 --n_embd=128 --max_iters=2000 --lr_decay_iters=2000 --dropout=0.0'
result = subprocess.run(command, shell=True, text=True, capture_output=True)
print(result.stdout)
# Out:
# Overriding config with config\train_shakespeare_char.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_dir = 'out-shakespeare-char'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 200
# log_interval = 10 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
# wandb_project = 'shakespeare-char'
# wandb_run_name = 'mini-gpt'
#
# dataset = 'shakespeare_char'
# gradient_accumulation_steps = 1
# batch_size = 64
# block_size = 256 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 6
# n_head = 6
# n_embd = 384
# dropout = 0.2
#
# learning_rate = 1e-3 # with baby networks can afford to go a bit higher
# max_iters = 5000
# lr_decay_iters = 5000 # make equal to max_iters usually
# min_lr = 1e-4 # learning_rate / 10 usually
# beta2 = 0.99 # make a bit bigger because number of tokens per iter is small
#
# warmup_iters = 100 # not super necessary potentially
#
# # on macbook also add
# # device = 'cpu'  # run on cpu only
# # compile = False # do not torch compile the model
#
# Overriding: device = cpu
# Overriding: compile = False
# Overriding: eval_iters = 20
# Overriding: log_interval = 1
# Overriding: block_size = 64
# Overriding: batch_size = 12
# Overriding: n_layer = 4
# Overriding: n_head = 4
# Overriding: n_embd = 128
# Overriding: max_iters = 2000
# Overriding: lr_decay_iters = 2000
# Overriding: dropout = 0.0
# tokens per iteration will be: 768
# found vocab_size = 65 (inside data\shakespeare_char\meta.pkl)
# Initializing a new model from scratch
# number of parameters: 0.80M
# num decayed parameter tensors: 18, with 802,944 parameters
# num non-decayed parameter tensors: 9, with 1,152 parameters
# using fused AdamW: False
# step 0: train loss 4.1676, val loss 4.1649
# iter 0: loss 4.1828, time 1189.66ms, mfu -100.00%
# iter 1: loss 4.1512, time 69.10ms, mfu -100.00%
# iter 2: loss 4.1654, time 43.22ms, mfu -100.00%
# iter 3: loss 4.1398, time 53.01ms, mfu -100.00%
# iter 4: loss 4.0927, time 63.62ms, mfu -100.00%
# iter 5: loss 4.0367, time 74.36ms, mfu 0.02%
# iter 6: loss 3.9746, time 81.02ms, mfu 0.02%
# iter 7: loss 3.9022, time 79.55ms, mfu 0.02%
# iter 8: loss 3.8626, time 97.57ms, mfu 0.02%
# iter 9: loss 3.7704, time 54.14ms, mfu 0.02%
# iter 10: loss 3.7665, time 60.00ms, mfu 0.02%
# iter 11: loss 3.7467, time 62.12ms, mfu 0.02%
# iter 12: loss 3.7263, time 69.96ms, mfu 0.02%
# iter 13: loss 3.6980, time 84.02ms, mfu 0.02%
# iter 14: loss 3.6628, time 81.80ms, mfu 0.02%
# iter 15: loss 3.6419, time 88.03ms, mfu 0.02%
# iter 16: loss 3.6213, time 88.65ms, mfu 0.02%
# iter 17: loss 3.6162, time 75.55ms, mfu 0.02%
# iter 18: loss 3.6407, time 86.59ms, mfu 0.02%
# iter 19: loss 3.6619, time 97.68ms, mfu 0.02%
# iter 20: loss 3.5484, time 89.52ms, mfu 0.02%
# iter 21: loss 3.5656, time 94.08ms, mfu 0.02%
# iter 22: loss 3.5263, time 86.78ms, mfu 0.02%
# iter 23: loss 3.5019, time 88.81ms, mfu 0.02%
# iter 24: loss 3.5342, time 88.99ms, mfu 0.02%
# iter 25: loss 3.3670, time 80.34ms, mfu 0.02%
# iter 26: loss 3.3540, time 90.14ms, mfu 0.02%
# iter 27: loss 3.3793, time 90.54ms, mfu 0.02%
# iter 28: loss 3.2957, time 90.30ms, mfu 0.02%
# iter 29: loss 3.3217, time 76.00ms, mfu 0.02%
# iter 30: loss 3.3526, time 87.06ms, mfu 0.02%
# iter 31: loss 3.2465, time 93.18ms, mfu 0.02%
# iter 32: loss 3.2195, time 83.26ms, mfu 0.02%
# iter 33: loss 3.2252, time 44.01ms, mfu 0.02%
# iter 34: loss 3.1642, time 73.75ms, mfu 0.02%
# iter 35: loss 3.2609, time 94.79ms, mfu 0.02%
# iter 36: loss 3.1577, time 71.50ms, mfu 0.02%
# iter 37: loss 3.1705, time 89.62ms, mfu 0.02%
# iter 38: loss 3.0329, time 95.27ms, mfu 0.02%
# iter 39: loss 3.0840, time 83.16ms, mfu 0.02%
# iter 40: loss 3.1115, time 91.47ms, mfu 0.02%
# iter 41: loss 3.0512, time 102.51ms, mfu 0.02%
# iter 42: loss 3.0016, time 110.88ms, mfu 0.01%
# iter 43: loss 2.9784, time 101.56ms, mfu 0.01%
# iter 44: loss 3.0152, time 103.62ms, mfu 0.01%
# iter 45: loss 2.9944, time 108.66ms, mfu 0.01%
# iter 46: loss 2.9305, time 105.96ms, mfu 0.01%
# iter 47: loss 3.0577, time 99.60ms, mfu 0.01%
# iter 48: loss 2.9505, time 100.99ms, mfu 0.01%
# iter 49: loss 2.9481, time 105.16ms, mfu 0.01%
# iter 50: loss 2.9463, time 102.93ms, mfu 0.01%
# iter 51: loss 2.9205, time 104.11ms, mfu 0.01%
# iter 52: loss 2.9232, time 105.41ms, mfu 0.01%
# iter 53: loss 2.9064, time 101.96ms, mfu 0.01%
# iter 54: loss 2.8243, time 107.90ms, mfu 0.01%
# iter 55: loss 2.8249, time 105.07ms, mfu 0.01%
# iter 56: loss 2.7912, time 103.79ms, mfu 0.01%
# iter 57: loss 2.8584, time 101.90ms, mfu 0.01%
# iter 58: loss 2.8226, time 83.85ms, mfu 0.01%
# iter 59: loss 2.8468, time 55.31ms, mfu 0.01%
# iter 60: loss 2.7946, time 88.73ms, mfu 0.01%
# iter 61: loss 2.8312, time 104.69ms, mfu 0.01%
# iter 62: loss 2.7602, time 100.41ms, mfu 0.01%
# iter 63: loss 2.8024, time 106.51ms, mfu 0.01%
# iter 64: loss 2.8022, time 110.59ms, mfu 0.01%
# iter 65: loss 2.7321, time 104.91ms, mfu 0.01%
# iter 66: loss 2.7658, time 109.36ms, mfu 0.01%
# iter 67: loss 2.7488, time 107.92ms, mfu 0.01%
# iter 68: loss 2.7737, time 104.32ms, mfu 0.01%
# iter 69: loss 2.7789, time 106.17ms, mfu 0.01%
# iter 70: loss 2.7076, time 103.80ms, mfu 0.01%
# iter 71: loss 2.7727, time 92.75ms, mfu 0.01%
# iter 72: loss 2.6684, time 78.16ms, mfu 0.01%
# iter 73: loss 2.7057, time 81.47ms, mfu 0.01%
# iter 74: loss 2.6562, time 91.21ms, mfu 0.01%
# iter 75: loss 2.7676, time 102.63ms, mfu 0.01%
# iter 76: loss 2.6640, time 120.73ms, mfu 0.01%
# iter 77: loss 2.7622, time 84.55ms, mfu 0.01%
# iter 78: loss 2.6759, time 90.57ms, mfu 0.01%
# iter 79: loss 2.6806, time 116.45ms, mfu 0.01%
# iter 80: loss 2.6173, time 101.66ms, mfu 0.01%
# iter 81: loss 2.6891, time 100.91ms, mfu 0.01%
# iter 82: loss 2.6911, time 102.13ms, mfu 0.01%
# iter 83: loss 2.6275, time 101.58ms, mfu 0.01%
# iter 84: loss 2.7292, time 101.80ms, mfu 0.01%
# iter 85: loss 2.6829, time 103.16ms, mfu 0.01%
# iter 86: loss 2.5994, time 105.36ms, mfu 0.01%
# iter 87: loss 2.6463, time 115.23ms, mfu 0.01%
# iter 88: loss 2.6111, time 99.85ms, mfu 0.01%
# iter 89: loss 2.7312, time 87.56ms, mfu 0.01%
# iter 90: loss 2.6180, time 100.58ms, mfu 0.01%
# iter 91: loss 2.6678, time 101.44ms, mfu 0.01%
# iter 92: loss 2.6055, time 103.34ms, mfu 0.01%
# iter 93: loss 2.5397, time 103.38ms, mfu 0.01%
# iter 94: loss 2.7052, time 102.62ms, mfu 0.01%
# iter 95: loss 2.6428, time 103.00ms, mfu 0.01%
# iter 96: loss 2.6829, time 103.59ms, mfu 0.01%
# iter 97: loss 2.5873, time 96.57ms, mfu 0.01%
# iter 98: loss 2.5377, time 84.58ms, mfu 0.01%
# iter 99: loss 2.6871, time 82.75ms, mfu 0.01%
# iter 100: loss 2.6648, time 78.15ms, mfu 0.01%
# iter 101: loss 2.6579, time 88.94ms, mfu 0.01%
# iter 102: loss 2.5922, time 84.17ms, mfu 0.01%
# iter 103: loss 2.6345, time 69.55ms, mfu 0.01%
# iter 104: loss 2.5047, time 84.60ms, mfu 0.01%
# iter 105: loss 2.5732, time 78.64ms, mfu 0.01%
# iter 106: loss 2.5281, time 87.51ms, mfu 0.01%
# iter 107: loss 2.5841, time 97.95ms, mfu 0.01%
# iter 108: loss 2.5639, time 93.60ms, mfu 0.01%
# iter 109: loss 2.5932, time 101.74ms, mfu 0.01%
# iter 110: loss 2.5891, time 100.39ms, mfu 0.01%
# iter 111: loss 2.5346, time 99.40ms, mfu 0.01%
# iter 112: loss 2.5361, time 97.93ms, mfu 0.01%
# iter 113: loss 2.5470, time 72.60ms, mfu 0.01%
# iter 114: loss 2.6048, time 90.77ms, mfu 0.01%
# iter 115: loss 2.5476, time 99.98ms, mfu 0.01%
# iter 116: loss 2.5759, time 100.14ms, mfu 0.01%
# iter 117: loss 2.5398, time 110.53ms, mfu 0.01%
# iter 118: loss 2.5895, time 82.81ms, mfu 0.01%
# iter 119: loss 2.6238, time 83.76ms, mfu 0.01%
# iter 120: loss 2.6206, time 87.20ms, mfu 0.01%
# iter 121: loss 2.7216, time 85.18ms, mfu 0.01%
# iter 122: loss 2.6038, time 61.14ms, mfu 0.01%
# iter 123: loss 2.5846, time 77.70ms, mfu 0.01%
# iter 124: loss 2.6185, time 79.60ms, mfu 0.02%
# iter 125: loss 2.5922, time 86.31ms, mfu 0.01%
# iter 126: loss 2.6086, time 77.78ms, mfu 0.02%
# iter 127: loss 2.6753, time 79.60ms, mfu 0.02%
# iter 128: loss 2.5911, time 72.90ms, mfu 0.02%
# iter 129: loss 2.5650, time 71.66ms, mfu 0.02%
# iter 130: loss 2.5459, time 65.83ms, mfu 0.02%
# iter 131: loss 2.7001, time 63.13ms, mfu 0.02%
# iter 132: loss 2.5248, time 69.39ms, mfu 0.02%
# iter 133: loss 2.5641, time 83.60ms, mfu 0.02%
# iter 134: loss 2.4341, time 53.47ms, mfu 0.02%
# iter 135: loss 2.5768, time 66.74ms, mfu 0.02%
# iter 136: loss 2.6012, time 73.19ms, mfu 0.02%
# iter 137: loss 2.5043, time 70.47ms, mfu 0.02%
# iter 138: loss 2.5159, time 72.48ms, mfu 0.02%
# iter 139: loss 2.5872, time 65.26ms, mfu 0.02%
# iter 140: loss 2.4944, time 70.94ms, mfu 0.02%
# iter 141: loss 2.5229, time 66.01ms, mfu 0.02%
# iter 142: loss 2.5430, time 65.01ms, mfu 0.02%
# iter 143: loss 2.5687, time 68.48ms, mfu 0.02%
# iter 144: loss 2.5464, time 48.20ms, mfu 0.02%
# iter 145: loss 2.5449, time 53.96ms, mfu 0.02%
# iter 146: loss 2.5041, time 73.39ms, mfu 0.02%
# iter 147: loss 2.5602, time 87.21ms, mfu 0.02%
# iter 148: loss 2.4698, time 99.48ms, mfu 0.02%
# iter 149: loss 2.5515, time 92.72ms, mfu 0.02%
# iter 150: loss 2.5360, time 99.71ms, mfu 0.02%
# iter 151: loss 2.5290, time 100.70ms, mfu 0.02%
# iter 152: loss 2.5725, time 101.64ms, mfu 0.02%
# iter 153: loss 2.4933, time 97.62ms, mfu 0.02%
# iter 154: loss 2.4579, time 104.54ms, mfu 0.02%
# iter 155: loss 2.4768, time 86.20ms, mfu 0.02%
# iter 156: loss 2.5000, time 91.21ms, mfu 0.02%
# iter 157: loss 2.5618, time 102.37ms, mfu 0.02%
# iter 158: loss 2.5761, time 107.15ms, mfu 0.01%
# iter 159: loss 2.5046, time 102.31ms, mfu 0.01%
# iter 160: loss 2.5293, time 101.63ms, mfu 0.01%
# iter 161: loss 2.4995, time 95.39ms, mfu 0.01%
# iter 162: loss 2.4577, time 88.51ms, mfu 0.01%
# iter 163: loss 2.4998, time 89.82ms, mfu 0.01%
# iter 164: loss 2.5111, time 97.51ms, mfu 0.01%
# iter 165: loss 2.6268, time 102.41ms, mfu 0.01%
# iter 166: loss 2.5130, time 101.34ms, mfu 0.01%
# iter 167: loss 2.4668, time 99.39ms, mfu 0.01%
# iter 168: loss 2.5482, time 114.64ms, mfu 0.01%
# iter 169: loss 2.4939, time 100.46ms, mfu 0.01%
# iter 170: loss 2.4728, time 109.84ms, mfu 0.01%
# iter 171: loss 2.3852, time 85.64ms, mfu 0.01%
# iter 172: loss 2.5197, time 81.83ms, mfu 0.01%
# iter 173: loss 2.5215, time 88.95ms, mfu 0.01%
# iter 174: loss 2.4674, time 126.42ms, mfu 0.01%
# iter 175: loss 2.4651, time 103.91ms, mfu 0.01%
# iter 176: loss 2.4536, time 92.61ms, mfu 0.01%
# iter 177: loss 2.4905, time 93.35ms, mfu 0.01%
# iter 178: loss 2.4806, time 100.34ms, mfu 0.01%
# iter 179: loss 2.6162, time 104.03ms, mfu 0.01%
# iter 180: loss 2.4912, time 98.96ms, mfu 0.01%
# iter 181: loss 2.4512, time 96.72ms, mfu 0.01%
# iter 182: loss 2.4419, time 93.60ms, mfu 0.01%
# iter 183: loss 2.5444, time 99.03ms, mfu 0.01%
# iter 184: loss 2.4474, time 101.22ms, mfu 0.01%
# iter 185: loss 2.5635, time 101.53ms, mfu 0.01%
# iter 186: loss 2.5666, time 102.08ms, mfu 0.01%
# iter 187: loss 2.5048, time 101.40ms, mfu 0.01%
# iter 188: loss 2.4850, time 112.19ms, mfu 0.01%
# iter 189: loss 2.5585, time 96.43ms, mfu 0.01%
# iter 190: loss 2.5454, time 98.38ms, mfu 0.01%
# iter 191: loss 2.5403, time 73.70ms, mfu 0.01%
# iter 192: loss 2.4553, time 72.10ms, mfu 0.01%
# iter 193: loss 2.5769, time 81.22ms, mfu 0.01%
# iter 194: loss 2.4814, time 90.29ms, mfu 0.01%
# iter 195: loss 2.4792, time 73.11ms, mfu 0.01%
# iter 196: loss 2.4719, time 77.02ms, mfu 0.01%
# iter 197: loss 2.4642, time 70.23ms, mfu 0.01%
# iter 198: loss 2.4504, time 63.91ms, mfu 0.02%
# iter 199: loss 2.4832, time 64.02ms, mfu 0.02%
# iter 200: loss 2.5010, time 72.19ms, mfu 0.02%
# iter 201: loss 2.4369, time 83.34ms, mfu 0.02%
# iter 202: loss 2.4480, time 92.48ms, mfu 0.02%
# iter 203: loss 2.5372, time 92.45ms, mfu 0.02%
# iter 204: loss 2.4791, time 92.05ms, mfu 0.02%
# iter 205: loss 2.4776, time 93.46ms, mfu 0.02%
# iter 206: loss 2.4714, time 79.05ms, mfu 0.02%
# iter 207: loss 2.5676, time 83.49ms, mfu 0.02%
# iter 208: loss 2.3839, time 89.65ms, mfu 0.02%
# iter 209: loss 2.5263, time 90.73ms, mfu 0.02%
# iter 210: loss 2.4342, time 78.09ms, mfu 0.02%
# iter 211: loss 2.5325, time 82.04ms, mfu 0.02%
# iter 212: loss 2.4722, time 87.33ms, mfu 0.02%
# iter 213: loss 2.4526, time 72.63ms, mfu 0.02%
# iter 214: loss 2.5307, time 72.06ms, mfu 0.02%
# iter 215: loss 2.5435, time 84.35ms, mfu 0.02%
# iter 216: loss 2.5083, time 92.58ms, mfu 0.02%
# iter 217: loss 2.4567, time 83.32ms, mfu 0.02%
# iter 218: loss 2.5047, time 97.91ms, mfu 0.02%
# iter 219: loss 2.4610, time 102.56ms, mfu 0.01%
# iter 220: loss 2.4930, time 103.12ms, mfu 0.01%
# iter 221: loss 2.5021, time 51.23ms, mfu 0.02%
# iter 222: loss 2.4631, time 44.38ms, mfu 0.02%
# iter 223: loss 2.5244, time 45.11ms, mfu 0.02%
# iter 224: loss 2.3972, time 48.63ms, mfu 0.02%
# iter 225: loss 2.5483, time 47.01ms, mfu 0.02%
# iter 226: loss 2.4776, time 57.18ms, mfu 0.02%
# iter 227: loss 2.4666, time 56.52ms, mfu 0.02%
# iter 228: loss 2.4509, time 45.51ms, mfu 0.02%
# iter 229: loss 2.5274, time 53.59ms, mfu 0.02%
# iter 230: loss 2.4650, time 58.04ms, mfu 0.02%
# iter 231: loss 2.4216, time 50.89ms, mfu 0.02%
# iter 232: loss 2.4467, time 51.01ms, mfu 0.02%
# iter 233: loss 2.4593, time 53.01ms, mfu 0.02%
# iter 234: loss 2.4191, time 52.92ms, mfu 0.02%
# iter 235: loss 2.4863, time 53.22ms, mfu 0.02%
# iter 236: loss 2.4418, time 54.05ms, mfu 0.02%
# iter 237: loss 2.4791, time 72.22ms, mfu 0.02%
# iter 238: loss 2.5074, time 67.90ms, mfu 0.02%
# iter 239: loss 2.4592, time 97.90ms, mfu 0.02%
# iter 240: loss 2.5153, time 80.48ms, mfu 0.02%
# iter 241: loss 2.4178, time 55.16ms, mfu 0.02%
# iter 242: loss 2.4862, time 65.23ms, mfu 0.02%
# iter 243: loss 2.4868, time 80.51ms, mfu 0.02%
# iter 244: loss 2.4040, time 72.81ms, mfu 0.02%
# iter 245: loss 2.5028, time 56.89ms, mfu 0.02%
# iter 246: loss 2.4063, time 66.88ms, mfu 0.02%
# iter 247: loss 2.4626, time 84.90ms, mfu 0.02%
# iter 248: loss 2.4512, time 93.69ms, mfu 0.02%
# iter 249: loss 2.4468, time 77.87ms, mfu 0.02%
# step 250: train loss 2.4317, val loss 2.4448
# saving checkpoint to out-shakespeare-char
# iter 250: loss 2.4973, time 901.59ms, mfu 0.02%
# iter 251: loss 2.3618, time 62.00ms, mfu 0.02%
# iter 252: loss 2.4911, time 73.99ms, mfu 0.02%
# iter 253: loss 2.4075, time 72.15ms, mfu 0.02%
# iter 254: loss 2.4045, time 70.52ms, mfu 0.02%
# iter 255: loss 2.4539, time 66.53ms, mfu 0.02%
# iter 256: loss 2.3598, time 77.60ms, mfu 0.02%
# iter 257: loss 2.3931, time 108.89ms, mfu 0.02%
# iter 258: loss 2.4068, time 58.13ms, mfu 0.02%
# iter 259: loss 2.3860, time 51.09ms, mfu 0.02%
# iter 260: loss 2.4447, time 72.19ms, mfu 0.02%
# iter 261: loss 2.4752, time 47.51ms, mfu 0.02%
# iter 262: loss 2.4478, time 70.29ms, mfu 0.02%
# iter 263: loss 2.4146, time 57.40ms, mfu 0.02%
# iter 264: loss 2.4715, time 71.52ms, mfu 0.02%
# iter 265: loss 2.4919, time 64.51ms, mfu 0.02%
# iter 266: loss 2.4309, time 62.67ms, mfu 0.02%
# iter 267: loss 2.3593, time 51.09ms, mfu 0.02%
# iter 268: loss 2.5305, time 62.28ms, mfu 0.02%
# iter 269: loss 2.4659, time 61.94ms, mfu 0.02%
# iter 270: loss 2.4113, time 62.56ms, mfu 0.02%
# iter 271: loss 2.4783, time 68.35ms, mfu 0.02%
# iter 272: loss 2.4249, time 45.27ms, mfu 0.02%
# iter 273: loss 2.3985, time 59.69ms, mfu 0.02%
# iter 274: loss 2.4074, time 68.55ms, mfu 0.02%
# iter 275: loss 2.4255, time 63.27ms, mfu 0.02%
# iter 276: loss 2.4109, time 60.41ms, mfu 0.02%
# iter 277: loss 2.3893, time 58.51ms, mfu 0.02%
# iter 278: loss 2.3850, time 57.73ms, mfu 0.02%
# iter 279: loss 2.3723, time 65.04ms, mfu 0.02%
# iter 280: loss 2.3816, time 71.00ms, mfu 0.02%
# iter 281: loss 2.4727, time 78.16ms, mfu 0.02%
# iter 282: loss 2.4090, time 79.04ms, mfu 0.02%
# iter 283: loss 2.4207, time 72.16ms, mfu 0.02%
# iter 284: loss 2.3995, time 79.63ms, mfu 0.02%
# iter 285: loss 2.4388, time 83.56ms, mfu 0.02%
# iter 286: loss 2.4539, time 74.69ms, mfu 0.02%
# iter 287: loss 2.4223, time 54.35ms, mfu 0.02%
# iter 288: loss 2.4318, time 70.91ms, mfu 0.02%
# iter 289: loss 2.3911, time 84.63ms, mfu 0.02%
# iter 290: loss 2.4047, time 80.00ms, mfu 0.02%
# iter 291: loss 2.3190, time 91.34ms, mfu 0.02%
# iter 292: loss 2.3932, time 91.31ms, mfu 0.02%
# iter 293: loss 2.3870, time 92.84ms, mfu 0.02%
# iter 294: loss 2.3249, time 72.44ms, mfu 0.02%
# iter 295: loss 2.4377, time 66.80ms, mfu 0.02%
# iter 296: loss 2.3251, time 69.96ms, mfu 0.02%
# iter 297: loss 2.3947, time 78.60ms, mfu 0.02%
# iter 298: loss 2.3473, time 82.41ms, mfu 0.02%
# iter 299: loss 2.3979, time 56.45ms, mfu 0.02%
# iter 300: loss 2.3445, time 86.19ms, mfu 0.02%
# iter 301: loss 2.2896, time 81.32ms, mfu 0.02%
# iter 302: loss 2.4536, time 58.78ms, mfu 0.02%
# iter 303: loss 2.4029, time 55.50ms, mfu 0.02%
# iter 304: loss 2.4922, time 60.00ms, mfu 0.02%
# iter 305: loss 2.4145, time 58.51ms, mfu 0.02%
# iter 306: loss 2.3809, time 71.78ms, mfu 0.02%
# iter 307: loss 2.3502, time 69.44ms, mfu 0.02%
# iter 308: loss 2.4315, time 73.48ms, mfu 0.02%
# iter 309: loss 2.4291, time 66.96ms, mfu 0.02%
# iter 310: loss 2.3552, time 81.73ms, mfu 0.02%
# iter 311: loss 2.4020, time 92.64ms, mfu 0.02%
# iter 312: loss 2.4580, time 84.08ms, mfu 0.02%
# iter 313: loss 2.4396, time 59.77ms, mfu 0.02%
# iter 314: loss 2.4781, time 67.48ms, mfu 0.02%
# iter 315: loss 2.4414, time 71.84ms, mfu 0.02%
# iter 316: loss 2.4493, time 53.38ms, mfu 0.02%
# iter 317: loss 2.3038, time 51.36ms, mfu 0.02%
# iter 318: loss 2.3875, time 50.31ms, mfu 0.02%
# iter 319: loss 2.4151, time 43.81ms, mfu 0.02%
# iter 320: loss 2.4118, time 61.38ms, mfu 0.02%
# iter 321: loss 2.3831, time 69.49ms, mfu 0.02%
# iter 322: loss 2.3895, time 76.08ms, mfu 0.02%
# iter 323: loss 2.4039, time 78.17ms, mfu 0.02%
# iter 324: loss 2.3999, time 52.52ms, mfu 0.02%
# iter 325: loss 2.3670, time 61.19ms, mfu 0.02%
# iter 326: loss 2.4708, time 77.47ms, mfu 0.02%
# iter 327: loss 2.3674, time 70.19ms, mfu 0.02%
# iter 328: loss 2.3829, time 64.62ms, mfu 0.02%
# iter 329: loss 2.3273, time 77.30ms, mfu 0.02%
# iter 330: loss 2.3290, time 63.11ms, mfu 0.02%
# iter 331: loss 2.4172, time 73.56ms, mfu 0.02%
# iter 332: loss 2.3458, time 81.44ms, mfu 0.02%
# iter 333: loss 2.4178, time 78.37ms, mfu 0.02%
# iter 334: loss 2.3937, time 86.80ms, mfu 0.02%
# iter 335: loss 2.3914, time 102.99ms, mfu 0.02%
# iter 336: loss 2.4209, time 93.73ms, mfu 0.02%
# iter 337: loss 2.3201, time 80.64ms, mfu 0.02%
# iter 338: loss 2.3627, time 85.20ms, mfu 0.02%
# iter 339: loss 2.4604, time 47.22ms, mfu 0.02%
# iter 340: loss 2.3399, time 42.68ms, mfu 0.02%
# iter 341: loss 2.3219, time 52.31ms, mfu 0.02%
# iter 342: loss 2.3083, time 82.90ms, mfu 0.02%
# iter 343: loss 2.3292, time 59.01ms, mfu 0.02%
# iter 344: loss 2.4011, time 78.93ms, mfu 0.02%
# iter 345: loss 2.3629, time 79.32ms, mfu 0.02%
# iter 346: loss 2.3651, time 70.19ms, mfu 0.02%
# iter 347: loss 2.3855, time 66.57ms, mfu 0.02%
# iter 348: loss 2.3176, time 69.72ms, mfu 0.02%
# iter 349: loss 2.3569, time 83.45ms, mfu 0.02%
# iter 350: loss 2.3469, time 87.61ms, mfu 0.02%
# iter 351: loss 2.2708, time 91.21ms, mfu 0.02%
# iter 352: loss 2.3750, time 81.76ms, mfu 0.02%
# iter 353: loss 2.4569, time 58.42ms, mfu 0.02%
# iter 354: loss 2.3698, time 64.83ms, mfu 0.02%
# iter 355: loss 2.4557, time 60.85ms, mfu 0.02%
# iter 356: loss 2.2876, time 86.75ms, mfu 0.02%
# iter 357: loss 2.3108, time 64.74ms, mfu 0.02%
# iter 358: loss 2.3451, time 81.99ms, mfu 0.02%
# iter 359: loss 2.3458, time 82.45ms, mfu 0.02%
# iter 360: loss 2.3961, time 77.99ms, mfu 0.02%
# iter 361: loss 2.2864, time 88.02ms, mfu 0.02%
# iter 362: loss 2.3844, time 80.58ms, mfu 0.02%
# iter 363: loss 2.3686, time 80.47ms, mfu 0.02%
# iter 364: loss 2.3647, time 90.33ms, mfu 0.02%
# iter 365: loss 2.3941, time 84.81ms, mfu 0.02%
# iter 366: loss 2.4251, time 73.72ms, mfu 0.02%
# iter 367: loss 2.3330, time 91.66ms, mfu 0.02%
# iter 368: loss 2.3741, time 51.12ms, mfu 0.02%
# iter 369: loss 2.3811, time 47.00ms, mfu 0.02%
# iter 370: loss 2.4841, time 51.33ms, mfu 0.02%
# iter 371: loss 2.3499, time 42.22ms, mfu 0.02%
# iter 372: loss 2.3112, time 47.36ms, mfu 0.02%
# iter 373: loss 2.3843, time 50.01ms, mfu 0.02%
# iter 374: loss 2.4027, time 62.49ms, mfu 0.02%
# iter 375: loss 2.2901, time 53.72ms, mfu 0.02%
# iter 376: loss 2.3647, time 68.21ms, mfu 0.02%
# iter 377: loss 2.3586, time 76.94ms, mfu 0.02%
# iter 378: loss 2.3696, time 75.63ms, mfu 0.02%
# iter 379: loss 2.3296, time 89.54ms, mfu 0.02%
# iter 380: loss 2.3368, time 91.49ms, mfu 0.02%
# iter 381: loss 2.2844, time 53.93ms, mfu 0.02%
# iter 382: loss 2.4087, time 53.63ms, mfu 0.02%
# iter 383: loss 2.3730, time 43.00ms, mfu 0.02%
# iter 384: loss 2.3091, time 43.58ms, mfu 0.02%
# iter 385: loss 2.3157, time 46.22ms, mfu 0.02%
# iter 386: loss 2.3395, time 41.88ms, mfu 0.02%
# iter 387: loss 2.3361, time 38.01ms, mfu 0.02%
# iter 388: loss 2.2580, time 43.50ms, mfu 0.02%
# iter 389: loss 2.3664, time 44.71ms, mfu 0.03%
# iter 390: loss 2.3506, time 41.51ms, mfu 0.03%
# iter 391: loss 2.4118, time 58.12ms, mfu 0.03%
# iter 392: loss 2.3034, time 56.13ms, mfu 0.02%
# iter 393: loss 2.3125, time 70.22ms, mfu 0.02%
# iter 394: loss 2.4655, time 62.15ms, mfu 0.02%
# iter 395: loss 2.3174, time 50.10ms, mfu 0.02%
# iter 396: loss 2.3736, time 42.55ms, mfu 0.02%
# iter 397: loss 2.3001, time 44.52ms, mfu 0.03%
# iter 398: loss 2.2165, time 50.99ms, mfu 0.03%
# iter 399: loss 2.3738, time 52.21ms, mfu 0.02%
# iter 400: loss 2.3360, time 51.77ms, mfu 0.02%
# iter 401: loss 2.3507, time 51.39ms, mfu 0.02%
# iter 402: loss 2.3684, time 47.00ms, mfu 0.03%
# iter 403: loss 2.3624, time 43.79ms, mfu 0.03%
# iter 404: loss 2.3436, time 40.53ms, mfu 0.03%
# iter 405: loss 2.4126, time 47.17ms, mfu 0.03%
# iter 406: loss 2.3425, time 48.94ms, mfu 0.03%
# iter 407: loss 2.3900, time 45.81ms, mfu 0.03%
# iter 408: loss 2.2759, time 45.57ms, mfu 0.03%
# iter 409: loss 2.3053, time 42.00ms, mfu 0.03%
# iter 410: loss 2.2766, time 43.52ms, mfu 0.03%
# iter 411: loss 2.3632, time 37.99ms, mfu 0.03%
# iter 412: loss 2.3453, time 47.21ms, mfu 0.03%
# iter 413: loss 2.3231, time 45.05ms, mfu 0.03%
# iter 414: loss 2.3479, time 42.00ms, mfu 0.03%
# iter 415: loss 2.4018, time 42.05ms, mfu 0.03%
# iter 416: loss 2.3273, time 46.22ms, mfu 0.03%
# iter 417: loss 2.2935, time 45.73ms, mfu 0.03%
# iter 418: loss 2.2811, time 45.94ms, mfu 0.03%
# iter 419: loss 2.2913, time 55.52ms, mfu 0.03%
# iter 420: loss 2.3765, time 44.42ms, mfu 0.03%
# iter 421: loss 2.2388, time 45.61ms, mfu 0.03%
# iter 422: loss 2.2910, time 52.80ms, mfu 0.03%
# iter 423: loss 2.3322, time 57.51ms, mfu 0.03%
# iter 424: loss 2.2708, time 57.12ms, mfu 0.03%
# iter 425: loss 2.3267, time 50.72ms, mfu 0.03%
# iter 426: loss 2.4085, time 55.08ms, mfu 0.03%
# iter 427: loss 2.3704, time 59.20ms, mfu 0.03%
# iter 428: loss 2.3067, time 51.69ms, mfu 0.03%
# iter 429: loss 2.2449, time 43.85ms, mfu 0.03%
# iter 430: loss 2.4063, time 42.56ms, mfu 0.03%
# iter 431: loss 2.3350, time 45.23ms, mfu 0.03%
# iter 432: loss 2.3398, time 41.00ms, mfu 0.03%
# iter 433: loss 2.2699, time 44.24ms, mfu 0.03%
# iter 434: loss 2.2916, time 39.00ms, mfu 0.03%
# iter 435: loss 2.2885, time 43.64ms, mfu 0.03%
# iter 436: loss 2.4051, time 41.66ms, mfu 0.03%
# iter 437: loss 2.2633, time 42.57ms, mfu 0.03%
# iter 438: loss 2.2877, time 54.53ms, mfu 0.03%
# iter 439: loss 2.2824, time 46.41ms, mfu 0.03%
# iter 440: loss 2.3555, time 42.76ms, mfu 0.03%
# iter 441: loss 2.3444, time 48.01ms, mfu 0.03%
# iter 442: loss 2.3542, time 45.51ms, mfu 0.03%
# iter 443: loss 2.3530, time 52.01ms, mfu 0.03%
# iter 444: loss 2.3526, time 69.45ms, mfu 0.03%
# iter 445: loss 2.2852, time 83.14ms, mfu 0.03%
# iter 446: loss 2.2861, time 88.86ms, mfu 0.02%
# iter 447: loss 2.3772, time 98.15ms, mfu 0.02%
# iter 448: loss 2.3755, time 111.20ms, mfu 0.02%
# iter 449: loss 2.3443, time 93.13ms, mfu 0.02%
# iter 450: loss 2.3408, time 87.80ms, mfu 0.02%
# iter 451: loss 2.3051, time 74.47ms, mfu 0.02%
# iter 452: loss 2.3532, time 100.82ms, mfu 0.02%
# iter 453: loss 2.3105, time 98.80ms, mfu 0.02%
# iter 454: loss 2.3415, time 97.10ms, mfu 0.02%
# iter 455: loss 2.3499, time 93.53ms, mfu 0.02%
# iter 456: loss 2.3174, time 101.71ms, mfu 0.02%
# iter 457: loss 2.2916, time 89.07ms, mfu 0.02%
# iter 458: loss 2.2795, time 105.92ms, mfu 0.02%
# iter 459: loss 2.3125, time 87.41ms, mfu 0.02%
# iter 460: loss 2.3273, time 79.52ms, mfu 0.02%
# iter 461: loss 2.3597, time 80.33ms, mfu 0.02%
# iter 462: loss 2.3881, time 87.01ms, mfu 0.02%
# iter 463: loss 2.3137, time 87.11ms, mfu 0.02%
# iter 464: loss 2.2893, time 88.19ms, mfu 0.02%
# iter 465: loss 2.2999, time 99.62ms, mfu 0.02%
# iter 466: loss 2.2941, time 83.53ms, mfu 0.02%
# iter 467: loss 2.2232, time 80.78ms, mfu 0.02%
# iter 468: loss 2.2863, time 86.08ms, mfu 0.02%
# iter 469: loss 2.2192, time 81.71ms, mfu 0.02%
# iter 470: loss 2.2912, time 82.56ms, mfu 0.02%
# iter 471: loss 2.2890, time 94.44ms, mfu 0.02%
# iter 472: loss 2.2644, time 81.79ms, mfu 0.02%
# iter 473: loss 2.2918, time 89.82ms, mfu 0.02%
# iter 474: loss 2.2111, time 66.35ms, mfu 0.02%
# iter 475: loss 2.3430, time 74.60ms, mfu 0.02%
# iter 476: loss 2.2821, time 90.78ms, mfu 0.02%
# iter 477: loss 2.3173, time 99.69ms, mfu 0.02%
# iter 478: loss 2.3496, time 57.53ms, mfu 0.02%
# iter 479: loss 2.2942, time 47.00ms, mfu 0.02%
# iter 480: loss 2.2204, time 48.61ms, mfu 0.02%
# iter 481: loss 2.2070, time 47.70ms, mfu 0.02%
# iter 482: loss 2.2997, time 41.16ms, mfu 0.02%
# iter 483: loss 2.2876, time 37.58ms, mfu 0.02%
# iter 484: loss 2.2700, time 49.38ms, mfu 0.02%
# iter 485: loss 2.2872, time 40.00ms, mfu 0.02%
# iter 486: loss 2.2835, time 38.92ms, mfu 0.02%
# iter 487: loss 2.2987, time 51.36ms, mfu 0.02%
# iter 488: loss 2.3205, time 43.00ms, mfu 0.02%
# iter 489: loss 2.2827, time 43.04ms, mfu 0.03%
# iter 490: loss 2.3210, time 42.78ms, mfu 0.03%
# iter 491: loss 2.3034, time 64.48ms, mfu 0.02%
# iter 492: loss 2.3939, time 41.20ms, mfu 0.03%
# iter 493: loss 2.1889, time 37.51ms, mfu 0.03%
# iter 494: loss 2.3487, time 44.01ms, mfu 0.03%
# iter 495: loss 2.2585, time 47.00ms, mfu 0.03%
# iter 496: loss 2.2654, time 54.15ms, mfu 0.03%
# iter 497: loss 2.2366, time 47.55ms, mfu 0.03%
# iter 498: loss 2.3075, time 58.01ms, mfu 0.03%
# iter 499: loss 2.2383, time 55.69ms, mfu 0.03%
# step 500: train loss 2.2800, val loss 2.3281
# saving checkpoint to out-shakespeare-char
# iter 500: loss 2.3838, time 773.28ms, mfu 0.02%
# iter 501: loss 2.2456, time 66.59ms, mfu 0.02%
# iter 502: loss 2.2743, time 69.58ms, mfu 0.02%
# iter 503: loss 2.2954, time 71.56ms, mfu 0.02%
# iter 504: loss 2.2902, time 71.02ms, mfu 0.02%
# iter 505: loss 2.4172, time 74.30ms, mfu 0.02%
# iter 506: loss 2.3040, time 70.51ms, mfu 0.02%
# iter 507: loss 2.2754, time 84.58ms, mfu 0.02%
# iter 508: loss 2.3905, time 78.38ms, mfu 0.02%
# iter 509: loss 2.2841, time 75.49ms, mfu 0.02%
# iter 510: loss 2.1983, time 75.69ms, mfu 0.02%
# iter 511: loss 2.2552, time 64.70ms, mfu 0.02%
# iter 512: loss 2.3081, time 62.92ms, mfu 0.02%
# iter 513: loss 2.2208, time 68.34ms, mfu 0.02%
# iter 514: loss 2.2140, time 71.10ms, mfu 0.02%
# iter 515: loss 2.2638, time 61.51ms, mfu 0.02%
# iter 516: loss 2.2186, time 60.28ms, mfu 0.02%
# iter 517: loss 2.3115, time 70.34ms, mfu 0.02%
# iter 518: loss 2.3110, time 45.31ms, mfu 0.02%
# iter 519: loss 2.3082, time 41.00ms, mfu 0.02%
# iter 520: loss 2.3279, time 51.69ms, mfu 0.02%
# iter 521: loss 2.2995, time 55.00ms, mfu 0.02%
# iter 522: loss 2.2808, time 59.52ms, mfu 0.02%
# iter 523: loss 2.2893, time 62.40ms, mfu 0.02%
# iter 524: loss 2.2278, time 58.22ms, mfu 0.02%
# iter 525: loss 2.2120, time 64.52ms, mfu 0.02%
# iter 526: loss 2.2193, time 58.01ms, mfu 0.02%
# iter 527: loss 2.3190, time 57.41ms, mfu 0.02%
# iter 528: loss 2.2119, time 57.42ms, mfu 0.02%
# iter 529: loss 2.2513, time 58.50ms, mfu 0.02%
# iter 530: loss 2.3086, time 52.10ms, mfu 0.02%
# iter 531: loss 2.2461, time 47.39ms, mfu 0.02%
# iter 532: loss 2.3136, time 48.01ms, mfu 0.02%
# iter 533: loss 2.2849, time 55.51ms, mfu 0.02%
# iter 534: loss 2.2333, time 52.83ms, mfu 0.02%
# iter 535: loss 2.2540, time 55.10ms, mfu 0.02%
# iter 536: loss 2.3268, time 53.31ms, mfu 0.02%
# iter 537: loss 2.2357, time 50.00ms, mfu 0.02%
# iter 538: loss 2.1930, time 49.53ms, mfu 0.02%
# iter 539: loss 2.1525, time 52.01ms, mfu 0.02%
# iter 540: loss 2.2589, time 50.10ms, mfu 0.02%
# iter 541: loss 2.2201, time 62.10ms, mfu 0.02%
# iter 542: loss 2.2913, time 55.26ms, mfu 0.02%
# iter 543: loss 2.4153, time 52.02ms, mfu 0.02%
# iter 544: loss 2.2835, time 50.30ms, mfu 0.02%
# iter 545: loss 2.2367, time 62.42ms, mfu 0.02%
# iter 546: loss 2.3090, time 50.30ms, mfu 0.02%
# iter 547: loss 2.2244, time 53.66ms, mfu 0.02%
# iter 548: loss 2.1890, time 58.26ms, mfu 0.02%
# iter 549: loss 2.2028, time 55.79ms, mfu 0.02%
# iter 550: loss 2.2055, time 56.25ms, mfu 0.02%
# iter 551: loss 2.2244, time 42.56ms, mfu 0.02%
# iter 552: loss 2.2413, time 36.99ms, mfu 0.02%
# iter 553: loss 2.3309, time 41.01ms, mfu 0.03%
# iter 554: loss 2.2035, time 45.51ms, mfu 0.03%
# iter 555: loss 2.2401, time 51.29ms, mfu 0.03%
# iter 556: loss 2.2342, time 51.48ms, mfu 0.03%
# iter 557: loss 2.1902, time 52.19ms, mfu 0.03%
# iter 558: loss 2.2216, time 69.03ms, mfu 0.02%
# iter 559: loss 2.2399, time 65.43ms, mfu 0.02%
# iter 560: loss 2.2343, time 70.51ms, mfu 0.02%
# iter 561: loss 2.2697, time 72.34ms, mfu 0.02%
# iter 562: loss 2.1353, time 70.71ms, mfu 0.02%
# iter 563: loss 2.1836, time 57.43ms, mfu 0.02%
# iter 564: loss 2.1920, time 57.98ms, mfu 0.02%
# iter 565: loss 2.1814, time 59.11ms, mfu 0.02%
# iter 566: loss 2.1757, time 71.61ms, mfu 0.02%
# iter 567: loss 2.2510, time 60.50ms, mfu 0.02%
# iter 568: loss 2.2555, time 61.60ms, mfu 0.02%
# iter 569: loss 2.2487, time 57.51ms, mfu 0.02%
# iter 570: loss 2.1016, time 62.98ms, mfu 0.02%
# iter 571: loss 2.1813, time 55.86ms, mfu 0.02%
# iter 572: loss 2.2560, time 57.93ms, mfu 0.02%
# iter 573: loss 2.2575, time 69.04ms, mfu 0.02%
# iter 574: loss 2.3219, time 58.51ms, mfu 0.02%
# iter 575: loss 2.2631, time 57.46ms, mfu 0.02%
# iter 576: loss 2.2303, time 53.22ms, mfu 0.02%
# iter 577: loss 2.2109, time 53.27ms, mfu 0.02%
# iter 578: loss 2.2952, time 52.30ms, mfu 0.02%
# iter 579: loss 2.2063, time 57.55ms, mfu 0.02%
# iter 580: loss 2.2138, time 57.24ms, mfu 0.02%
# iter 581: loss 2.3231, time 64.80ms, mfu 0.02%
# iter 582: loss 2.2068, time 69.73ms, mfu 0.02%
# iter 583: loss 2.2312, time 69.66ms, mfu 0.02%
# iter 584: loss 2.2067, time 81.97ms, mfu 0.02%
# iter 585: loss 2.2267, time 86.77ms, mfu 0.02%
# iter 586: loss 2.2118, time 84.22ms, mfu 0.02%
# iter 587: loss 2.2388, time 72.88ms, mfu 0.02%
# iter 588: loss 2.2330, time 65.01ms, mfu 0.02%
# iter 589: loss 2.1340, time 57.64ms, mfu 0.02%
# iter 590: loss 2.2116, time 55.00ms, mfu 0.02%
# iter 591: loss 2.1126, time 64.10ms, mfu 0.02%
# iter 592: loss 2.1896, time 62.78ms, mfu 0.02%
# iter 593: loss 2.2626, time 60.07ms, mfu 0.02%
# iter 594: loss 2.1501, time 59.45ms, mfu 0.02%
# iter 595: loss 2.1624, time 60.53ms, mfu 0.02%
# iter 596: loss 2.2449, time 64.37ms, mfu 0.02%
# iter 597: loss 2.2547, time 68.11ms, mfu 0.02%
# iter 598: loss 2.2133, time 65.01ms, mfu 0.02%
# iter 599: loss 2.1702, time 69.56ms, mfu 0.02%
# iter 600: loss 2.1717, time 60.72ms, mfu 0.02%
# iter 601: loss 2.2238, time 57.72ms, mfu 0.02%
# iter 602: loss 2.1935, time 54.73ms, mfu 0.02%
# iter 603: loss 2.1881, time 54.38ms, mfu 0.02%
# iter 604: loss 2.1993, time 56.21ms, mfu 0.02%
# iter 605: loss 2.2088, time 63.57ms, mfu 0.02%
# iter 606: loss 2.2429, time 64.46ms, mfu 0.02%
# iter 607: loss 2.2323, time 66.53ms, mfu 0.02%
# iter 608: loss 2.2132, time 55.68ms, mfu 0.02%
# iter 609: loss 2.1855, time 57.00ms, mfu 0.02%
# iter 610: loss 2.1825, time 63.39ms, mfu 0.02%
# iter 611: loss 2.1134, time 70.73ms, mfu 0.02%
# iter 612: loss 2.1765, time 69.91ms, mfu 0.02%
# iter 613: loss 2.1552, time 70.20ms, mfu 0.02%
# iter 614: loss 2.1851, time 70.06ms, mfu 0.02%
# iter 615: loss 2.2699, time 72.58ms, mfu 0.02%
# iter 616: loss 2.1555, time 60.13ms, mfu 0.02%
# iter 617: loss 2.2058, time 56.05ms, mfu 0.02%
# iter 618: loss 2.2263, time 62.54ms, mfu 0.02%
# iter 619: loss 2.2078, time 54.69ms, mfu 0.02%
# iter 620: loss 2.1836, time 53.75ms, mfu 0.02%
# iter 621: loss 2.1953, time 58.60ms, mfu 0.02%
# iter 622: loss 2.2260, time 55.65ms, mfu 0.02%
# iter 623: loss 2.1921, time 62.30ms, mfu 0.02%
# iter 624: loss 2.1903, time 63.13ms, mfu 0.02%
# iter 625: loss 2.1791, time 69.37ms, mfu 0.02%
# iter 626: loss 2.1630, time 76.34ms, mfu 0.02%
# iter 627: loss 2.1410, time 72.59ms, mfu 0.02%
# iter 628: loss 2.1653, time 94.12ms, mfu 0.02%
# iter 629: loss 2.2414, time 91.13ms, mfu 0.02%
# iter 630: loss 2.1598, time 66.55ms, mfu 0.02%
# iter 631: loss 2.1254, time 61.92ms, mfu 0.02%
# iter 632: loss 2.2246, time 56.76ms, mfu 0.02%
# iter 633: loss 2.1745, time 51.00ms, mfu 0.02%
# iter 634: loss 2.2760, time 48.03ms, mfu 0.02%
# iter 635: loss 2.2268, time 41.07ms, mfu 0.02%
# iter 636: loss 2.2024, time 51.06ms, mfu 0.02%
# iter 637: loss 2.1378, time 66.22ms, mfu 0.02%
# iter 638: loss 2.1752, time 64.34ms, mfu 0.02%
# iter 639: loss 2.2381, time 56.82ms, mfu 0.02%
# iter 640: loss 2.1115, time 63.61ms, mfu 0.02%
# iter 641: loss 2.2037, time 67.99ms, mfu 0.02%
# iter 642: loss 2.2406, time 72.32ms, mfu 0.02%
# iter 643: loss 2.1947, time 80.17ms, mfu 0.02%
# iter 644: loss 2.1989, time 76.41ms, mfu 0.02%
# iter 645: loss 2.1423, time 59.03ms, mfu 0.02%
# iter 646: loss 2.2037, time 45.02ms, mfu 0.02%
# iter 647: loss 2.1991, time 44.69ms, mfu 0.02%
# iter 648: loss 2.1292, time 47.13ms, mfu 0.02%
# iter 649: loss 2.1968, time 50.52ms, mfu 0.02%
# iter 650: loss 2.1318, time 46.32ms, mfu 0.02%
# iter 651: loss 2.1499, time 55.86ms, mfu 0.02%
# iter 652: loss 2.1935, time 62.17ms, mfu 0.02%
# iter 653: loss 2.2700, time 55.91ms, mfu 0.02%
# iter 654: loss 2.1556, time 61.15ms, mfu 0.02%
# iter 655: loss 2.1786, time 68.26ms, mfu 0.02%
# iter 656: loss 2.2167, time 62.98ms, mfu 0.02%
# iter 657: loss 2.2591, time 64.12ms, mfu 0.02%
# iter 658: loss 2.3073, time 61.08ms, mfu 0.02%
# iter 659: loss 2.0733, time 68.79ms, mfu 0.02%
# iter 660: loss 2.2250, time 67.87ms, mfu 0.02%
# iter 661: loss 2.1895, time 78.60ms, mfu 0.02%
# iter 662: loss 2.1785, time 56.74ms, mfu 0.02%
# iter 663: loss 2.1680, time 59.45ms, mfu 0.02%
# iter 664: loss 2.1171, time 76.53ms, mfu 0.02%
# iter 665: loss 2.1537, time 62.02ms, mfu 0.02%
# iter 666: loss 2.1207, time 53.04ms, mfu 0.02%
# iter 667: loss 2.2261, time 60.46ms, mfu 0.02%
# iter 668: loss 2.2227, time 58.81ms, mfu 0.02%
# iter 669: loss 2.1791, time 67.25ms, mfu 0.02%
# iter 670: loss 2.1112, time 77.87ms, mfu 0.02%
# iter 671: loss 2.2000, time 48.99ms, mfu 0.02%
# iter 672: loss 2.2335, time 46.11ms, mfu 0.02%
# iter 673: loss 2.1606, time 47.74ms, mfu 0.02%
# iter 674: loss 2.1520, time 45.04ms, mfu 0.02%
# iter 675: loss 2.2599, time 40.08ms, mfu 0.02%
# iter 676: loss 2.2441, time 42.99ms, mfu 0.02%
# iter 677: loss 2.2112, time 51.50ms, mfu 0.02%
# iter 678: loss 2.1735, time 45.92ms, mfu 0.02%
# iter 679: loss 2.1417, time 49.32ms, mfu 0.02%
# iter 680: loss 2.1624, time 46.01ms, mfu 0.02%
# iter 681: loss 2.2543, time 52.04ms, mfu 0.02%
# iter 682: loss 2.2058, time 47.99ms, mfu 0.03%
# iter 683: loss 2.1528, time 40.79ms, mfu 0.03%
# iter 684: loss 2.1648, time 44.01ms, mfu 0.03%
# iter 685: loss 2.1803, time 45.54ms, mfu 0.03%
# iter 686: loss 2.1111, time 58.03ms, mfu 0.03%
# iter 687: loss 2.0946, time 59.26ms, mfu 0.03%
# iter 688: loss 2.2103, time 53.23ms, mfu 0.03%
# iter 689: loss 2.1144, time 63.44ms, mfu 0.02%
# iter 690: loss 2.0830, time 63.81ms, mfu 0.02%
# iter 691: loss 2.0583, time 71.49ms, mfu 0.02%
# iter 692: loss 2.1452, time 72.59ms, mfu 0.02%
# iter 693: loss 2.2021, time 65.84ms, mfu 0.02%
# iter 694: loss 2.1982, time 63.38ms, mfu 0.02%
# iter 695: loss 2.0030, time 59.50ms, mfu 0.02%
# iter 696: loss 2.1436, time 74.65ms, mfu 0.02%
# iter 697: loss 2.2544, time 39.92ms, mfu 0.02%
# iter 698: loss 2.1549, time 44.00ms, mfu 0.02%
# iter 699: loss 2.1720, time 50.10ms, mfu 0.02%
# iter 700: loss 2.1069, time 53.83ms, mfu 0.02%
# iter 701: loss 2.0988, time 62.60ms, mfu 0.02%
# iter 702: loss 2.2359, time 70.32ms, mfu 0.02%
# iter 703: loss 2.1885, time 70.15ms, mfu 0.02%
# iter 704: loss 2.0658, time 57.74ms, mfu 0.02%
# iter 705: loss 2.1182, time 50.87ms, mfu 0.02%
# iter 706: loss 2.2135, time 57.33ms, mfu 0.02%
# iter 707: loss 2.0578, time 59.77ms, mfu 0.02%
# iter 708: loss 2.0905, time 50.00ms, mfu 0.02%
# iter 709: loss 2.1805, time 48.01ms, mfu 0.02%
# iter 710: loss 2.1944, time 47.76ms, mfu 0.02%
# iter 711: loss 2.1246, time 48.13ms, mfu 0.02%
# iter 712: loss 2.2364, time 43.41ms, mfu 0.02%
# iter 713: loss 2.0290, time 42.69ms, mfu 0.02%
# iter 714: loss 2.0725, time 47.27ms, mfu 0.03%
# iter 715: loss 2.0507, time 48.34ms, mfu 0.03%
# iter 716: loss 2.1275, time 43.29ms, mfu 0.03%
# iter 717: loss 2.1679, time 40.82ms, mfu 0.03%
# iter 718: loss 2.1270, time 55.33ms, mfu 0.03%
# iter 719: loss 2.1165, time 57.38ms, mfu 0.03%
# iter 720: loss 2.1149, time 54.39ms, mfu 0.03%
# iter 721: loss 2.2506, time 64.56ms, mfu 0.02%
# iter 722: loss 2.0910, time 68.50ms, mfu 0.02%
# iter 723: loss 2.0770, time 46.92ms, mfu 0.02%
# iter 724: loss 2.0978, time 50.69ms, mfu 0.02%
# iter 725: loss 2.2160, time 41.57ms, mfu 0.03%
# iter 726: loss 2.1411, time 54.48ms, mfu 0.02%
# iter 727: loss 2.1010, time 57.50ms, mfu 0.02%
# iter 728: loss 2.1527, time 64.20ms, mfu 0.02%
# iter 729: loss 2.1586, time 69.06ms, mfu 0.02%
# iter 730: loss 2.1864, time 67.64ms, mfu 0.02%
# iter 731: loss 2.1612, time 73.36ms, mfu 0.02%
# iter 732: loss 2.1246, time 42.76ms, mfu 0.02%
# iter 733: loss 2.0920, time 43.80ms, mfu 0.02%
# iter 734: loss 2.0778, time 51.33ms, mfu 0.02%
# iter 735: loss 2.1048, time 42.36ms, mfu 0.02%
# iter 736: loss 2.1083, time 50.93ms, mfu 0.02%
# iter 737: loss 2.2696, time 52.01ms, mfu 0.02%
# iter 738: loss 2.0251, time 50.36ms, mfu 0.02%
# iter 739: loss 2.1295, time 48.77ms, mfu 0.02%
# iter 740: loss 2.1260, time 51.48ms, mfu 0.02%
# iter 741: loss 2.0385, time 57.56ms, mfu 0.02%
# iter 742: loss 2.1419, time 57.39ms, mfu 0.02%
# iter 743: loss 2.1756, time 45.56ms, mfu 0.02%
# iter 744: loss 2.1191, time 47.97ms, mfu 0.02%
# iter 745: loss 2.0834, time 44.33ms, mfu 0.03%
# iter 746: loss 2.0892, time 41.04ms, mfu 0.03%
# iter 747: loss 2.0568, time 41.09ms, mfu 0.03%
# iter 748: loss 2.0695, time 49.94ms, mfu 0.03%
# iter 749: loss 2.0826, time 49.20ms, mfu 0.03%
# step 750: train loss 2.1241, val loss 2.1780
# saving checkpoint to out-shakespeare-char
# iter 750: loss 2.0689, time 688.76ms, mfu 0.02%
# iter 751: loss 2.1351, time 86.13ms, mfu 0.02%
# iter 752: loss 2.1241, time 75.14ms, mfu 0.02%
# iter 753: loss 2.0507, time 64.00ms, mfu 0.02%
# iter 754: loss 2.1300, time 74.31ms, mfu 0.02%
# iter 755: loss 2.0475, time 87.14ms, mfu 0.02%
# iter 756: loss 2.0463, time 66.14ms, mfu 0.02%
# iter 757: loss 2.1233, time 65.90ms, mfu 0.02%
# iter 758: loss 2.1296, time 51.80ms, mfu 0.02%
# iter 759: loss 2.1421, time 44.63ms, mfu 0.02%
# iter 760: loss 2.1910, time 40.89ms, mfu 0.02%
# iter 761: loss 2.1746, time 37.94ms, mfu 0.02%
# iter 762: loss 2.1388, time 42.45ms, mfu 0.02%
# iter 763: loss 2.1295, time 40.22ms, mfu 0.03%
# iter 764: loss 2.1518, time 40.83ms, mfu 0.03%
# iter 765: loss 2.0914, time 41.51ms, mfu 0.03%
# iter 766: loss 2.1440, time 41.15ms, mfu 0.03%
# iter 767: loss 2.1421, time 39.09ms, mfu 0.03%
# iter 768: loss 2.1273, time 38.66ms, mfu 0.03%
# iter 769: loss 2.0917, time 39.46ms, mfu 0.03%
# iter 770: loss 2.1055, time 38.87ms, mfu 0.03%
# iter 771: loss 2.1123, time 39.00ms, mfu 0.03%
# iter 772: loss 2.1410, time 43.63ms, mfu 0.03%
# iter 773: loss 2.1369, time 48.55ms, mfu 0.03%
# iter 774: loss 2.0502, time 42.85ms, mfu 0.03%
# iter 775: loss 2.0319, time 47.51ms, mfu 0.03%
# iter 776: loss 2.1240, time 47.94ms, mfu 0.03%
# iter 777: loss 2.0960, time 50.06ms, mfu 0.03%
# iter 778: loss 2.0870, time 51.84ms, mfu 0.03%
# iter 779: loss 2.1167, time 43.28ms, mfu 0.03%
# iter 780: loss 2.0850, time 69.28ms, mfu 0.03%
# iter 781: loss 2.0224, time 64.77ms, mfu 0.03%
# iter 782: loss 2.0884, time 37.81ms, mfu 0.03%
# iter 783: loss 2.1879, time 44.00ms, mfu 0.03%
# iter 784: loss 2.2712, time 56.48ms, mfu 0.03%
# iter 785: loss 2.0447, time 70.72ms, mfu 0.03%
# iter 786: loss 2.0346, time 51.69ms, mfu 0.03%
# iter 787: loss 2.0715, time 60.17ms, mfu 0.03%
# iter 788: loss 2.2400, time 47.04ms, mfu 0.03%
# iter 789: loss 2.1616, time 40.73ms, mfu 0.03%
# iter 790: loss 2.0242, time 45.25ms, mfu 0.03%
# iter 791: loss 2.1123, time 87.14ms, mfu 0.03%
# iter 792: loss 2.0018, time 90.73ms, mfu 0.02%
# iter 793: loss 2.1018, time 95.67ms, mfu 0.02%
# iter 794: loss 2.1233, time 106.73ms, mfu 0.02%
# iter 795: loss 2.2059, time 99.95ms, mfu 0.02%
# iter 796: loss 2.1890, time 100.63ms, mfu 0.02%
# iter 797: loss 2.1556, time 94.83ms, mfu 0.02%
# iter 798: loss 2.1321, time 96.98ms, mfu 0.02%
# iter 799: loss 2.0641, time 95.19ms, mfu 0.02%
# iter 800: loss 2.2303, time 95.94ms, mfu 0.02%
# iter 801: loss 2.1282, time 95.77ms, mfu 0.02%
# iter 802: loss 2.1159, time 62.74ms, mfu 0.02%
# iter 803: loss 2.1360, time 75.91ms, mfu 0.02%
# iter 804: loss 2.1133, time 71.07ms, mfu 0.02%
# iter 805: loss 2.1099, time 65.14ms, mfu 0.02%
# iter 806: loss 2.1162, time 82.64ms, mfu 0.02%
# iter 807: loss 1.9887, time 85.24ms, mfu 0.02%
# iter 808: loss 2.1898, time 76.15ms, mfu 0.02%
# iter 809: loss 2.1369, time 79.87ms, mfu 0.02%
# iter 810: loss 2.0326, time 84.25ms, mfu 0.02%
# iter 811: loss 2.1726, time 82.86ms, mfu 0.02%
# iter 812: loss 2.0892, time 91.81ms, mfu 0.02%
# iter 813: loss 2.1087, time 88.73ms, mfu 0.02%
# iter 814: loss 2.1193, time 82.01ms, mfu 0.02%
# iter 815: loss 2.2251, time 50.03ms, mfu 0.02%
# iter 816: loss 2.0991, time 52.53ms, mfu 0.02%
# iter 817: loss 2.0618, time 57.25ms, mfu 0.02%
# iter 818: loss 2.0449, time 67.84ms, mfu 0.02%
# iter 819: loss 2.1651, time 65.25ms, mfu 0.02%
# iter 820: loss 2.0649, time 60.34ms, mfu 0.02%
# iter 821: loss 2.0589, time 71.83ms, mfu 0.02%
# iter 822: loss 2.1224, time 80.97ms, mfu 0.02%
# iter 823: loss 2.0505, time 72.01ms, mfu 0.02%
# iter 824: loss 2.0179, time 82.14ms, mfu 0.02%
# iter 825: loss 2.1081, time 89.32ms, mfu 0.02%
# iter 826: loss 2.1092, time 85.93ms, mfu 0.02%
# iter 827: loss 2.1070, time 57.68ms, mfu 0.02%
# iter 828: loss 2.0769, time 80.39ms, mfu 0.02%
# iter 829: loss 1.9881, time 75.89ms, mfu 0.02%
# iter 830: loss 2.0298, time 67.52ms, mfu 0.02%
# iter 831: loss 2.1387, time 56.03ms, mfu 0.02%
# iter 832: loss 2.0207, time 63.94ms, mfu 0.02%
# iter 833: loss 2.0970, time 79.17ms, mfu 0.02%
# iter 834: loss 2.1513, time 104.16ms, mfu 0.02%
# iter 835: loss 2.1453, time 97.11ms, mfu 0.02%
# iter 836: loss 2.0362, time 89.89ms, mfu 0.02%
# iter 837: loss 2.2172, time 66.94ms, mfu 0.02%
# iter 838: loss 2.1223, time 66.64ms, mfu 0.02%
# iter 839: loss 2.1325, time 65.21ms, mfu 0.02%
# iter 840: loss 2.0759, time 65.17ms, mfu 0.02%
# iter 841: loss 2.0162, time 66.42ms, mfu 0.02%
# iter 842: loss 2.0810, time 72.29ms, mfu 0.02%
# iter 843: loss 2.0444, time 79.10ms, mfu 0.02%
# iter 844: loss 2.1649, time 80.64ms, mfu 0.02%
# iter 845: loss 2.0135, time 86.93ms, mfu 0.02%
# iter 846: loss 2.1006, time 87.81ms, mfu 0.02%
# iter 847: loss 1.9829, time 91.26ms, mfu 0.02%
# iter 848: loss 1.9888, time 72.80ms, mfu 0.02%
# iter 849: loss 2.0544, time 80.22ms, mfu 0.02%
# iter 850: loss 2.0922, time 42.01ms, mfu 0.02%
# iter 851: loss 2.1230, time 46.89ms, mfu 0.02%
# iter 852: loss 2.0801, time 62.51ms, mfu 0.02%
# iter 853: loss 2.1052, time 71.29ms, mfu 0.02%
# iter 854: loss 2.0650, time 70.69ms, mfu 0.02%
# iter 855: loss 2.0682, time 73.51ms, mfu 0.02%
# iter 856: loss 1.9714, time 67.77ms, mfu 0.02%
# iter 857: loss 2.1840, time 66.00ms, mfu 0.02%
# iter 858: loss 2.0796, time 72.95ms, mfu 0.02%
# iter 859: loss 2.1375, time 76.04ms, mfu 0.02%
# iter 860: loss 2.1395, time 46.00ms, mfu 0.02%
# iter 861: loss 2.0189, time 52.93ms, mfu 0.02%
# iter 862: loss 2.0362, time 57.08ms, mfu 0.02%
# iter 863: loss 2.0290, time 64.22ms, mfu 0.02%
# iter 864: loss 1.8831, time 61.15ms, mfu 0.02%
# iter 865: loss 2.0607, time 41.60ms, mfu 0.02%
# iter 866: loss 2.0473, time 42.25ms, mfu 0.02%
# iter 867: loss 2.0038, time 46.10ms, mfu 0.02%
# iter 868: loss 2.1051, time 47.68ms, mfu 0.02%
# iter 869: loss 2.0654, time 53.04ms, mfu 0.02%
# iter 870: loss 2.1034, time 54.66ms, mfu 0.02%
# iter 871: loss 2.0471, time 55.45ms, mfu 0.02%
# iter 872: loss 2.0690, time 67.71ms, mfu 0.02%
# iter 873: loss 2.0775, time 75.82ms, mfu 0.02%
# iter 874: loss 2.0663, time 80.92ms, mfu 0.02%
# iter 875: loss 2.0942, time 66.52ms, mfu 0.02%
# iter 876: loss 2.0867, time 76.55ms, mfu 0.02%
# iter 877: loss 2.0959, time 107.43ms, mfu 0.02%
# iter 878: loss 2.0895, time 63.94ms, mfu 0.02%
# iter 879: loss 2.0076, time 80.20ms, mfu 0.02%
# iter 880: loss 2.0584, time 61.72ms, mfu 0.02%
# iter 881: loss 2.0143, time 65.51ms, mfu 0.02%
# iter 882: loss 2.0060, time 70.51ms, mfu 0.02%
# iter 883: loss 2.0707, time 72.91ms, mfu 0.02%
# iter 884: loss 2.0358, time 68.88ms, mfu 0.02%
# iter 885: loss 2.0508, time 71.41ms, mfu 0.02%
# iter 886: loss 1.9493, time 69.51ms, mfu 0.02%
# iter 887: loss 1.9569, time 79.64ms, mfu 0.02%
# iter 888: loss 2.0573, time 81.79ms, mfu 0.02%
# iter 889: loss 2.0714, time 68.46ms, mfu 0.02%
# iter 890: loss 1.9715, time 62.84ms, mfu 0.02%
# iter 891: loss 2.0172, time 59.07ms, mfu 0.02%
# iter 892: loss 2.0542, time 58.52ms, mfu 0.02%
# iter 893: loss 2.0203, time 67.27ms, mfu 0.02%
# iter 894: loss 2.0388, time 68.05ms, mfu 0.02%
# iter 895: loss 2.0079, time 78.36ms, mfu 0.02%
# iter 896: loss 2.1426, time 65.99ms, mfu 0.02%
# iter 897: loss 2.0016, time 78.36ms, mfu 0.02%
# iter 898: loss 2.0519, time 58.80ms, mfu 0.02%
# iter 899: loss 2.0528, time 39.51ms, mfu 0.02%
# iter 900: loss 2.0244, time 47.55ms, mfu 0.02%
# iter 901: loss 2.0333, time 55.30ms, mfu 0.02%
# iter 902: loss 2.0709, time 64.47ms, mfu 0.02%
# iter 903: loss 2.0658, time 61.31ms, mfu 0.02%
# iter 904: loss 2.0948, time 63.59ms, mfu 0.02%
# iter 905: loss 2.0360, time 68.36ms, mfu 0.02%
# iter 906: loss 2.1472, time 66.99ms, mfu 0.02%
# iter 907: loss 2.0795, time 67.74ms, mfu 0.02%
# iter 908: loss 2.0236, time 63.33ms, mfu 0.02%
# iter 909: loss 1.9721, time 67.88ms, mfu 0.02%
# iter 910: loss 1.9386, time 63.51ms, mfu 0.02%
# iter 911: loss 2.0262, time 70.22ms, mfu 0.02%
# iter 912: loss 2.1357, time 79.34ms, mfu 0.02%
# iter 913: loss 2.0505, time 45.04ms, mfu 0.02%
# iter 914: loss 2.0468, time 50.83ms, mfu 0.02%
# iter 915: loss 2.0437, time 52.42ms, mfu 0.02%
# iter 916: loss 2.1078, time 70.06ms, mfu 0.02%
# iter 917: loss 1.9676, time 71.04ms, mfu 0.02%
# iter 918: loss 2.0177, time 72.05ms, mfu 0.02%
# iter 919: loss 2.0995, time 43.51ms, mfu 0.02%
# iter 920: loss 2.0682, time 67.52ms, mfu 0.02%
# iter 921: loss 1.9825, time 50.83ms, mfu 0.02%
# iter 922: loss 2.1142, time 48.87ms, mfu 0.02%
# iter 923: loss 2.0627, time 58.90ms, mfu 0.02%
# iter 924: loss 1.9782, time 69.25ms, mfu 0.02%
# iter 925: loss 1.9756, time 74.38ms, mfu 0.02%
# iter 926: loss 2.0321, time 70.44ms, mfu 0.02%
# iter 927: loss 1.9911, time 60.89ms, mfu 0.02%
# iter 928: loss 2.0136, time 71.19ms, mfu 0.02%
# iter 929: loss 1.9976, time 70.91ms, mfu 0.02%
# iter 930: loss 2.0921, time 87.04ms, mfu 0.02%
# iter 931: loss 1.9896, time 75.35ms, mfu 0.02%
# iter 932: loss 2.0419, time 82.81ms, mfu 0.02%
# iter 933: loss 2.0044, time 88.58ms, mfu 0.02%
# iter 934: loss 1.9768, time 90.24ms, mfu 0.02%
# iter 935: loss 2.1721, time 72.34ms, mfu 0.02%
# iter 936: loss 2.0557, time 89.86ms, mfu 0.02%
# iter 937: loss 2.0656, time 81.96ms, mfu 0.02%
# iter 938: loss 2.0338, time 74.85ms, mfu 0.02%
# iter 939: loss 2.1121, time 64.15ms, mfu 0.02%
# iter 940: loss 1.9331, time 58.94ms, mfu 0.02%
# iter 941: loss 2.1295, time 64.33ms, mfu 0.02%
# iter 942: loss 2.0209, time 78.72ms, mfu 0.02%
# iter 943: loss 2.0692, time 80.16ms, mfu 0.02%
# iter 944: loss 2.1878, time 89.99ms, mfu 0.02%
# iter 945: loss 2.0207, time 92.24ms, mfu 0.02%
# iter 946: loss 2.0371, time 101.82ms, mfu 0.02%
# iter 947: loss 2.1619, time 102.62ms, mfu 0.02%
# iter 948: loss 2.0367, time 100.40ms, mfu 0.02%
# iter 949: loss 2.0008, time 90.60ms, mfu 0.02%
# iter 950: loss 2.0068, time 88.65ms, mfu 0.02%
# iter 951: loss 2.0096, time 79.04ms, mfu 0.02%
# iter 952: loss 1.9209, time 84.92ms, mfu 0.02%
# iter 953: loss 2.0357, time 78.77ms, mfu 0.02%
# iter 954: loss 1.9554, time 85.09ms, mfu 0.02%
# iter 955: loss 1.9237, time 66.79ms, mfu 0.02%
# iter 956: loss 1.9696, time 42.52ms, mfu 0.02%
# iter 957: loss 2.0578, time 46.56ms, mfu 0.02%
# iter 958: loss 1.9775, time 61.24ms, mfu 0.02%
# iter 959: loss 2.0628, time 71.23ms, mfu 0.02%
# iter 960: loss 2.0934, time 80.40ms, mfu 0.02%
# iter 961: loss 2.0506, time 91.23ms, mfu 0.02%
# iter 962: loss 1.8677, time 79.33ms, mfu 0.02%
# iter 963: loss 2.0281, time 76.49ms, mfu 0.02%
# iter 964: loss 1.9562, time 91.93ms, mfu 0.02%
# iter 965: loss 2.0881, time 91.28ms, mfu 0.02%
# iter 966: loss 2.0409, time 98.24ms, mfu 0.02%
# iter 967: loss 2.0190, time 102.01ms, mfu 0.02%
# iter 968: loss 1.9782, time 92.46ms, mfu 0.02%
# iter 969: loss 2.0558, time 59.84ms, mfu 0.02%
# iter 970: loss 2.0060, time 48.03ms, mfu 0.02%
# iter 971: loss 2.0305, time 61.16ms, mfu 0.02%
# iter 972: loss 2.0180, time 59.02ms, mfu 0.02%
# iter 973: loss 2.0375, time 58.64ms, mfu 0.02%
# iter 974: loss 2.0544, time 72.24ms, mfu 0.02%
# iter 975: loss 2.0237, time 79.39ms, mfu 0.02%
# ...
# iter 1672: loss 1.8119, time 81.64ms, mfu 0.02%
# iter 1673: loss 1.8310, time 81.56ms, mfu 0.02%
# iter 1674: loss 1.8125, time 100.49ms, mfu 0.02%
# iter 1675: loss 1.8026, time 82.67ms, mfu 0.02%
# iter 1676: loss 1.8262, time 78.42ms, mfu 0.02%
# iter 1677: loss 1.8673, time 89.24ms, mfu 0.02%
# iter 1678: loss 1.7848, time 94.54ms, mfu 0.02%
# iter 1679: loss 1.8516, time 75.71ms, mfu 0.02%
# iter 1680: loss 1.8468, time 78.64ms, mfu 0.02%
# iter 1681: loss 1.8590, time 83.63ms, mfu 0.02%
# iter 1682: loss 1.7152, time 84.81ms, mfu 0.02%
# iter 1683: loss 1.7852, time 96.21ms, mfu 0.02%
# iter 1684: loss 1.7867, time 97.82ms, mfu 0.02%
# iter 1685: loss 1.7410, time 100.24ms, mfu 0.02%
# iter 1686: loss 1.8516, time 110.41ms, mfu 0.02%
# iter 1687: loss 1.8050, time 98.29ms, mfu 0.02%
# iter 1688: loss 1.8003, time 89.36ms, mfu 0.01%
# iter 1689: loss 1.6991, time 47.07ms, mfu 0.02%
# iter 1690: loss 1.8434, time 56.40ms, mfu 0.02%
# iter 1691: loss 1.8396, time 70.52ms, mfu 0.02%
# iter 1692: loss 1.8906, time 94.70ms, mfu 0.02%
# iter 1693: loss 1.8013, time 84.58ms, mfu 0.02%
# iter 1694: loss 1.8551, time 91.13ms, mfu 0.02%
# iter 1695: loss 1.7403, time 94.15ms, mfu 0.02%
# iter 1696: loss 1.7679, time 96.60ms, mfu 0.02%
# iter 1697: loss 1.8058, time 98.75ms, mfu 0.02%
# iter 1698: loss 1.8261, time 103.26ms, mfu 0.02%
# iter 1699: loss 1.8569, time 92.49ms, mfu 0.01%
# iter 1700: loss 1.6972, time 98.55ms, mfu 0.01%
# iter 1701: loss 1.7871, time 58.05ms, mfu 0.02%
# iter 1702: loss 1.8985, time 56.01ms, mfu 0.02%
# iter 1703: loss 1.8233, time 78.46ms, mfu 0.02%
# iter 1704: loss 1.6024, time 100.29ms, mfu 0.02%
# iter 1705: loss 1.8108, time 96.07ms, mfu 0.02%
# iter 1706: loss 1.7600, time 110.07ms, mfu 0.02%
# iter 1707: loss 1.8670, time 103.65ms, mfu 0.01%
# iter 1708: loss 1.8186, time 62.17ms, mfu 0.02%
# iter 1709: loss 1.7891, time 45.00ms, mfu 0.02%
# iter 1710: loss 1.8125, time 52.52ms, mfu 0.02%
# iter 1711: loss 1.9001, time 71.60ms, mfu 0.02%
# iter 1712: loss 1.9234, time 80.38ms, mfu 0.02%
# iter 1713: loss 1.8144, time 74.34ms, mfu 0.02%
# iter 1714: loss 1.8980, time 70.30ms, mfu 0.02%
# iter 1715: loss 1.7965, time 67.16ms, mfu 0.02%
# iter 1716: loss 1.8010, time 87.69ms, mfu 0.02%
# iter 1717: loss 1.8358, time 90.74ms, mfu 0.02%
# iter 1718: loss 1.7802, time 89.09ms, mfu 0.02%
# iter 1719: loss 1.8094, time 84.43ms, mfu 0.02%
# iter 1720: loss 1.8272, time 94.67ms, mfu 0.02%
# iter 1721: loss 1.8697, time 88.68ms, mfu 0.02%
# iter 1722: loss 1.8048, time 88.11ms, mfu 0.02%
# iter 1723: loss 1.8101, time 90.96ms, mfu 0.02%
# iter 1724: loss 1.7791, time 96.44ms, mfu 0.02%
# iter 1725: loss 1.8090, time 96.58ms, mfu 0.02%
# iter 1726: loss 1.7773, time 88.00ms, mfu 0.02%
# iter 1727: loss 1.8266, time 94.58ms, mfu 0.01%
# iter 1728: loss 1.8409, time 89.02ms, mfu 0.01%
# iter 1729: loss 1.9394, time 73.89ms, mfu 0.02%
# iter 1730: loss 1.7953, time 85.74ms, mfu 0.02%
# iter 1731: loss 1.7377, time 91.02ms, mfu 0.01%
# iter 1732: loss 1.7071, time 100.53ms, mfu 0.01%
# iter 1733: loss 1.8378, time 96.75ms, mfu 0.01%
# iter 1734: loss 1.7461, time 103.96ms, mfu 0.01%
# iter 1735: loss 1.7765, time 104.05ms, mfu 0.01%
# iter 1736: loss 1.8869, time 100.07ms, mfu 0.01%
# iter 1737: loss 1.7845, time 93.93ms, mfu 0.01%
# iter 1738: loss 1.7369, time 92.47ms, mfu 0.01%
# iter 1739: loss 1.7370, time 100.84ms, mfu 0.01%
# iter 1740: loss 1.7420, time 97.27ms, mfu 0.01%
# iter 1741: loss 1.7649, time 93.30ms, mfu 0.01%
# iter 1742: loss 1.8613, time 96.52ms, mfu 0.01%
# iter 1743: loss 1.7942, time 103.21ms, mfu 0.01%
# iter 1744: loss 1.7542, time 110.73ms, mfu 0.01%
# iter 1745: loss 1.7268, time 106.90ms, mfu 0.01%
# iter 1746: loss 1.7700, time 99.75ms, mfu 0.01%
# iter 1747: loss 1.6940, time 99.83ms, mfu 0.01%
# iter 1748: loss 1.8107, time 104.99ms, mfu 0.01%
# iter 1749: loss 1.7426, time 103.01ms, mfu 0.01%
# step 1750: train loss 1.7772, val loss 1.8988
# saving checkpoint to out-shakespeare-char
# iter 1750: loss 1.8118, time 976.58ms, mfu 0.01%
# iter 1751: loss 1.9276, time 82.09ms, mfu 0.01%
# iter 1752: loss 1.8138, time 89.57ms, mfu 0.01%
# iter 1753: loss 1.6841, time 102.27ms, mfu 0.01%
# iter 1754: loss 1.8709, time 70.53ms, mfu 0.01%
# iter 1755: loss 1.8054, time 80.05ms, mfu 0.01%
# iter 1756: loss 1.7943, time 86.26ms, mfu 0.01%
# iter 1757: loss 1.7298, time 91.30ms, mfu 0.01%
# iter 1758: loss 1.7226, time 72.51ms, mfu 0.01%
# iter 1759: loss 1.7773, time 89.36ms, mfu 0.01%
# iter 1760: loss 1.7115, time 92.89ms, mfu 0.01%
# iter 1761: loss 1.7288, time 94.50ms, mfu 0.01%
# iter 1762: loss 1.7645, time 50.16ms, mfu 0.01%
# iter 1763: loss 1.8901, time 55.16ms, mfu 0.02%
# iter 1764: loss 1.8298, time 60.51ms, mfu 0.02%
# iter 1765: loss 1.7491, time 66.30ms, mfu 0.02%
# iter 1766: loss 1.8066, time 55.90ms, mfu 0.02%
# iter 1767: loss 1.8376, time 69.28ms, mfu 0.02%
# iter 1768: loss 1.8923, time 52.00ms, mfu 0.02%
# iter 1769: loss 1.7709, time 68.82ms, mfu 0.02%
# iter 1770: loss 1.6520, time 71.03ms, mfu 0.02%
# iter 1771: loss 1.7975, time 74.51ms, mfu 0.02%
# iter 1772: loss 1.7438, time 77.12ms, mfu 0.02%
# iter 1773: loss 1.8250, time 77.76ms, mfu 0.02%
# iter 1774: loss 1.7931, time 81.12ms, mfu 0.02%
# iter 1775: loss 1.7792, time 81.37ms, mfu 0.02%
# iter 1776: loss 1.6529, time 61.18ms, mfu 0.02%
# iter 1777: loss 1.8321, time 82.62ms, mfu 0.02%
# iter 1778: loss 1.7486, time 94.68ms, mfu 0.02%
# iter 1779: loss 1.9489, time 99.60ms, mfu 0.02%
# iter 1780: loss 1.7237, time 87.40ms, mfu 0.02%
# iter 1781: loss 1.8477, time 98.50ms, mfu 0.02%
# iter 1782: loss 1.9347, time 99.25ms, mfu 0.02%
# iter 1783: loss 1.7396, time 95.34ms, mfu 0.02%
# iter 1784: loss 1.8108, time 72.65ms, mfu 0.02%
# iter 1785: loss 1.8027, time 57.62ms, mfu 0.02%
# iter 1786: loss 1.7769, time 63.05ms, mfu 0.02%
# iter 1787: loss 1.8133, time 74.40ms, mfu 0.02%
# iter 1788: loss 1.7952, time 67.21ms, mfu 0.02%
# iter 1789: loss 1.7555, time 85.06ms, mfu 0.02%
# iter 1790: loss 1.7881, time 81.70ms, mfu 0.02%
# iter 1791: loss 1.7521, time 107.08ms, mfu 0.02%
# iter 1792: loss 1.8289, time 98.30ms, mfu 0.02%
# iter 1793: loss 1.8171, time 79.28ms, mfu 0.02%
# iter 1794: loss 1.7838, time 70.62ms, mfu 0.02%
# iter 1795: loss 1.7697, time 74.37ms, mfu 0.02%
# iter 1796: loss 1.8839, time 77.62ms, mfu 0.02%
# iter 1797: loss 1.7541, time 86.23ms, mfu 0.02%
# iter 1798: loss 1.7626, time 84.94ms, mfu 0.02%
# iter 1799: loss 1.7286, time 80.00ms, mfu 0.02%
# iter 1800: loss 1.8400, time 90.57ms, mfu 0.02%
# iter 1801: loss 1.8156, time 76.41ms, mfu 0.02%
# iter 1802: loss 1.8103, time 85.19ms, mfu 0.02%
# iter 1803: loss 1.6746, time 91.40ms, mfu 0.02%
# iter 1804: loss 1.8208, time 119.62ms, mfu 0.02%
# iter 1805: loss 1.7271, time 66.86ms, mfu 0.02%
# iter 1806: loss 1.7339, time 54.82ms, mfu 0.02%
# iter 1807: loss 1.8290, time 60.09ms, mfu 0.02%
# iter 1808: loss 1.8589, time 62.82ms, mfu 0.02%
# iter 1809: loss 1.8565, time 56.33ms, mfu 0.02%
# iter 1810: loss 1.8660, time 61.29ms, mfu 0.02%
# iter 1811: loss 1.7385, time 57.91ms, mfu 0.02%
# iter 1812: loss 1.7706, time 57.19ms, mfu 0.02%
# iter 1813: loss 1.8120, time 59.81ms, mfu 0.02%
# iter 1814: loss 1.8350, time 62.59ms, mfu 0.02%
# iter 1815: loss 1.8890, time 61.64ms, mfu 0.02%
# iter 1816: loss 1.6737, time 51.80ms, mfu 0.02%
# iter 1817: loss 1.7851, time 55.79ms, mfu 0.02%
# iter 1818: loss 1.8275, time 58.38ms, mfu 0.02%
# iter 1819: loss 1.6800, time 57.63ms, mfu 0.02%
# iter 1820: loss 1.6982, time 67.98ms, mfu 0.02%
# iter 1821: loss 1.6996, time 68.46ms, mfu 0.02%
# iter 1822: loss 1.7388, time 75.08ms, mfu 0.02%
# iter 1823: loss 1.7215, time 67.89ms, mfu 0.02%
# iter 1824: loss 1.6366, time 72.98ms, mfu 0.02%
# iter 1825: loss 1.6995, time 71.94ms, mfu 0.02%
# iter 1826: loss 1.7167, time 66.55ms, mfu 0.02%
# iter 1827: loss 1.8017, time 65.99ms, mfu 0.02%
# iter 1828: loss 1.7928, time 60.08ms, mfu 0.02%
# iter 1829: loss 1.9013, time 71.15ms, mfu 0.02%
# iter 1830: loss 1.7554, time 69.57ms, mfu 0.02%
# iter 1831: loss 1.8456, time 71.93ms, mfu 0.02%
# iter 1832: loss 1.7123, time 62.51ms, mfu 0.02%
# iter 1833: loss 1.8779, time 58.37ms, mfu 0.02%
# iter 1834: loss 1.8617, time 56.48ms, mfu 0.02%
# iter 1835: loss 1.8834, time 57.69ms, mfu 0.02%
# iter 1836: loss 1.7719, time 52.72ms, mfu 0.02%
# iter 1837: loss 1.8271, time 68.44ms, mfu 0.02%
# iter 1838: loss 1.6246, time 64.74ms, mfu 0.02%
# iter 1839: loss 1.8030, time 77.24ms, mfu 0.02%
# iter 1840: loss 1.8013, time 77.55ms, mfu 0.02%
# iter 1841: loss 1.7456, time 66.10ms, mfu 0.02%
# iter 1842: loss 1.7717, time 68.03ms, mfu 0.02%
# iter 1843: loss 1.8780, time 64.66ms, mfu 0.02%
# iter 1844: loss 1.7673, time 60.29ms, mfu 0.02%
# iter 1845: loss 1.8352, time 65.19ms, mfu 0.02%
# iter 1846: loss 1.7183, time 53.34ms, mfu 0.02%
# iter 1847: loss 1.6900, time 59.14ms, mfu 0.02%
# iter 1848: loss 1.7445, time 54.51ms, mfu 0.02%
# iter 1849: loss 1.8950, time 58.37ms, mfu 0.02%
# iter 1850: loss 1.7209, time 59.08ms, mfu 0.02%
# iter 1851: loss 1.7155, time 66.00ms, mfu 0.02%
# iter 1852: loss 1.7293, time 63.37ms, mfu 0.02%
# iter 1853: loss 1.8254, time 65.52ms, mfu 0.02%
# iter 1854: loss 1.6849, time 55.22ms, mfu 0.02%
# iter 1855: loss 1.6783, time 52.94ms, mfu 0.02%
# iter 1856: loss 1.8192, time 57.48ms, mfu 0.02%
# iter 1857: loss 1.8314, time 65.62ms, mfu 0.02%
# iter 1858: loss 1.9077, time 67.29ms, mfu 0.02%
# iter 1859: loss 1.7418, time 76.42ms, mfu 0.02%
# iter 1860: loss 1.6939, time 87.94ms, mfu 0.02%
# iter 1861: loss 1.6504, time 83.14ms, mfu 0.02%
# iter 1862: loss 1.7254, time 75.34ms, mfu 0.02%
# iter 1863: loss 1.7180, time 69.16ms, mfu 0.02%
# iter 1864: loss 1.6714, time 71.06ms, mfu 0.02%
# iter 1865: loss 1.8140, time 88.05ms, mfu 0.02%
# iter 1866: loss 1.7684, time 85.53ms, mfu 0.02%
# iter 1867: loss 1.7317, time 86.97ms, mfu 0.02%
# iter 1868: loss 1.7342, time 84.87ms, mfu 0.02%
# iter 1869: loss 1.8124, time 89.48ms, mfu 0.02%
# iter 1870: loss 1.6761, time 75.39ms, mfu 0.02%
# iter 1871: loss 1.7885, time 84.72ms, mfu 0.02%
# iter 1872: loss 1.7640, time 76.79ms, mfu 0.02%
# iter 1873: loss 1.7464, time 76.70ms, mfu 0.02%
# iter 1874: loss 1.7015, time 76.96ms, mfu 0.02%
# iter 1875: loss 1.7001, time 86.14ms, mfu 0.02%
# iter 1876: loss 1.7360, time 88.30ms, mfu 0.02%
# iter 1877: loss 1.7516, time 101.06ms, mfu 0.02%
# iter 1878: loss 1.6881, time 92.91ms, mfu 0.02%
# iter 1879: loss 1.7708, time 91.58ms, mfu 0.02%
# iter 1880: loss 1.7420, time 89.30ms, mfu 0.02%
# iter 1881: loss 1.7803, time 100.60ms, mfu 0.02%
# iter 1882: loss 1.8759, time 73.48ms, mfu 0.02%
# iter 1883: loss 1.6348, time 50.51ms, mfu 0.02%
# iter 1884: loss 1.7098, time 57.24ms, mfu 0.02%
# iter 1885: loss 1.7775, time 60.13ms, mfu 0.02%
# iter 1886: loss 1.6892, time 58.45ms, mfu 0.02%
# iter 1887: loss 1.8178, time 58.60ms, mfu 0.02%
# iter 1888: loss 1.7148, time 59.40ms, mfu 0.02%
# iter 1889: loss 1.7248, time 57.62ms, mfu 0.02%
# iter 1890: loss 1.6935, time 60.10ms, mfu 0.02%
# iter 1891: loss 1.7327, time 60.14ms, mfu 0.02%
# iter 1892: loss 1.6702, time 57.18ms, mfu 0.02%
# iter 1893: loss 1.7573, time 64.10ms, mfu 0.02%
# iter 1894: loss 1.7360, time 55.41ms, mfu 0.02%
# iter 1895: loss 1.7401, time 63.01ms, mfu 0.02%
# iter 1896: loss 1.7345, time 47.23ms, mfu 0.02%
# iter 1897: loss 1.7268, time 51.99ms, mfu 0.02%
# iter 1898: loss 1.7862, time 61.19ms, mfu 0.02%
# iter 1899: loss 1.7122, time 60.11ms, mfu 0.02%
# iter 1900: loss 1.6888, time 54.47ms, mfu 0.02%
# iter 1901: loss 1.7770, time 53.67ms, mfu 0.02%
# iter 1902: loss 1.8061, time 55.32ms, mfu 0.02%
# iter 1903: loss 1.8835, time 60.94ms, mfu 0.02%
# iter 1904: loss 1.7113, time 62.50ms, mfu 0.02%
# iter 1905: loss 1.7313, time 70.64ms, mfu 0.02%
# iter 1906: loss 1.6474, time 82.41ms, mfu 0.02%
# iter 1907: loss 1.8164, time 76.52ms, mfu 0.02%
# iter 1908: loss 1.7298, time 79.21ms, mfu 0.02%
# iter 1909: loss 1.8726, time 94.42ms, mfu 0.02%
# iter 1910: loss 1.6071, time 93.07ms, mfu 0.02%
# iter 1911: loss 1.7469, time 81.64ms, mfu 0.02%
# iter 1912: loss 1.7300, time 83.87ms, mfu 0.02%
# iter 1913: loss 1.7724, time 86.05ms, mfu 0.02%
# iter 1914: loss 1.7306, time 88.90ms, mfu 0.02%
# iter 1915: loss 1.8379, time 93.10ms, mfu 0.02%
# iter 1916: loss 1.6871, time 89.77ms, mfu 0.02%
# iter 1917: loss 1.7457, time 92.06ms, mfu 0.02%
# iter 1918: loss 1.7876, time 86.91ms, mfu 0.02%
# iter 1919: loss 1.6843, time 82.43ms, mfu 0.02%
# iter 1920: loss 1.7771, time 81.69ms, mfu 0.02%
# iter 1921: loss 1.7857, time 87.04ms, mfu 0.02%
# iter 1922: loss 1.7753, time 88.90ms, mfu 0.02%
# iter 1923: loss 1.7651, time 78.27ms, mfu 0.02%
# iter 1924: loss 1.7285, time 72.21ms, mfu 0.02%
# iter 1925: loss 1.7435, time 79.06ms, mfu 0.02%
# iter 1926: loss 1.8810, time 86.70ms, mfu 0.02%
# iter 1927: loss 1.9401, time 103.62ms, mfu 0.02%
# iter 1928: loss 1.6877, time 91.89ms, mfu 0.02%
# iter 1929: loss 1.7051, time 100.32ms, mfu 0.02%
# iter 1930: loss 1.7856, time 91.10ms, mfu 0.01%
# iter 1931: loss 1.7806, time 100.90ms, mfu 0.01%
# iter 1932: loss 1.8156, time 79.38ms, mfu 0.01%
# iter 1933: loss 1.7806, time 57.64ms, mfu 0.02%
# iter 1934: loss 1.7936, time 57.06ms, mfu 0.02%
# iter 1935: loss 1.7190, time 67.22ms, mfu 0.02%
# iter 1936: loss 1.6887, time 72.37ms, mfu 0.02%
# iter 1937: loss 1.8156, time 107.78ms, mfu 0.02%
# iter 1938: loss 1.7138, time 72.08ms, mfu 0.02%
# iter 1939: loss 1.7316, time 49.97ms, mfu 0.02%
# iter 1940: loss 1.7075, time 64.16ms, mfu 0.02%
# iter 1941: loss 1.6616, time 52.33ms, mfu 0.02%
# iter 1942: loss 1.7628, time 55.57ms, mfu 0.02%
# iter 1943: loss 1.7964, time 56.93ms, mfu 0.02%
# iter 1944: loss 1.8005, time 56.77ms, mfu 0.02%
# iter 1945: loss 1.7875, time 58.01ms, mfu 0.02%
# iter 1946: loss 1.6925, time 60.07ms, mfu 0.02%
# iter 1947: loss 1.8008, time 50.00ms, mfu 0.02%
# iter 1948: loss 1.7996, time 66.51ms, mfu 0.02%
# iter 1949: loss 1.6567, time 68.65ms, mfu 0.02%
# iter 1950: loss 1.7634, time 55.39ms, mfu 0.02%
# iter 1951: loss 1.8534, time 58.88ms, mfu 0.02%
# iter 1952: loss 1.6319, time 71.78ms, mfu 0.02%
# iter 1953: loss 1.8580, time 97.77ms, mfu 0.02%
# iter 1954: loss 1.7344, time 54.72ms, mfu 0.02%
# iter 1955: loss 1.9020, time 59.35ms, mfu 0.02%
# iter 1956: loss 1.7554, time 57.42ms, mfu 0.02%
# iter 1957: loss 1.7179, time 54.01ms, mfu 0.02%
# iter 1958: loss 1.8236, time 54.50ms, mfu 0.02%
# iter 1959: loss 1.7714, time 49.55ms, mfu 0.02%
# iter 1960: loss 1.7544, time 57.01ms, mfu 0.02%
# iter 1961: loss 1.7261, time 55.12ms, mfu 0.02%
# iter 1962: loss 1.8845, time 63.28ms, mfu 0.02%
# iter 1963: loss 1.6660, time 50.29ms, mfu 0.02%
# iter 1964: loss 1.7198, time 48.99ms, mfu 0.02%
# iter 1965: loss 1.8136, time 55.56ms, mfu 0.02%
# iter 1966: loss 1.7715, time 55.75ms, mfu 0.02%
# iter 1967: loss 1.9631, time 55.02ms, mfu 0.02%
# iter 1968: loss 1.6566, time 62.15ms, mfu 0.02%
# iter 1969: loss 1.7731, time 59.07ms, mfu 0.02%
# iter 1970: loss 1.8156, time 67.13ms, mfu 0.02%
# iter 1971: loss 1.7697, time 64.76ms, mfu 0.02%
# iter 1972: loss 1.7430, time 72.08ms, mfu 0.02%
# iter 1973: loss 1.7213, time 67.82ms, mfu 0.02%
# iter 1974: loss 1.7055, time 51.25ms, mfu 0.02%
# iter 1975: loss 1.7309, time 57.61ms, mfu 0.02%
# iter 1976: loss 1.7049, time 54.71ms, mfu 0.02%
# iter 1977: loss 1.9077, time 64.95ms, mfu 0.02%
# iter 1978: loss 1.7551, time 69.33ms, mfu 0.02%
# iter 1979: loss 1.7734, time 52.42ms, mfu 0.02%
# iter 1980: loss 1.7564, time 60.18ms, mfu 0.02%
# iter 1981: loss 1.7911, time 66.55ms, mfu 0.02%
# iter 1982: loss 1.7584, time 57.88ms, mfu 0.02%
# iter 1983: loss 1.7616, time 62.85ms, mfu 0.02%
# iter 1984: loss 1.6947, time 54.70ms, mfu 0.02%
# iter 1985: loss 1.7296, time 65.84ms, mfu 0.02%
# iter 1986: loss 1.6805, time 64.94ms, mfu 0.02%
# iter 1987: loss 1.7116, time 71.05ms, mfu 0.02%
# iter 1988: loss 1.7144, time 79.02ms, mfu 0.02%
# iter 1989: loss 1.6907, time 100.24ms, mfu 0.02%
# iter 1990: loss 1.7094, time 95.49ms, mfu 0.02%
# iter 1991: loss 1.7544, time 70.52ms, mfu 0.02%
# iter 1992: loss 1.6759, time 56.44ms, mfu 0.02%
# iter 1993: loss 1.8366, time 56.68ms, mfu 0.02%
# iter 1994: loss 1.7542, time 56.26ms, mfu 0.02%
# iter 1995: loss 1.7653, time 49.40ms, mfu 0.02%
# iter 1996: loss 1.8247, time 55.98ms, mfu 0.02%
# iter 1997: loss 1.7162, time 55.21ms, mfu 0.02%
# iter 1998: loss 1.8794, time 56.52ms, mfu 0.02%
# iter 1999: loss 1.9167, time 59.55ms, mfu 0.02%
# step 2000: train loss 1.7640, val loss 1.8925
# saving checkpoint to out-shakespeare-char
# iter 2000: loss 1.6982, time 825.34ms, mfu 0.02%

# %%
# Heuristic ruld: number of 's

# %%
# count number of 's
def count_s(text):
    count = text.count('\'s')
    return count

# %%
# Generate text by sample.py

def generate_text(seed):
    sample_script = os.path.join("sample.py")
    out_dir = "out-shakespeare-char"
    command = f'python "{sample_script}" --out_dir="{out_dir}" --device=cpu --seed={seed}'
    result = subprocess.run(command, shell=True, text=True, capture_output=True)
    output = result.stdout
    
    # remove the first line
    output = output.split('\n\n', 1)[1]
    
    return output

# five tries

results = {'text': [], 'count': []}

for i in range(20):
    output = generate_text(i)

    # count number of 's
    count = count_s(output)

    results['text'].append(output)
    results['count'].append(count)

# %%
import pandas as pd

df = pd.DataFrame(results)

# keep some outputs as evaluation
df_eval = df.sample(5, random_state=1)
df = df.drop(df_eval.index)

# generate cartesian product
df['key'] = 1
df2 = df.copy()
df2.columns = ['text2', 'count2', 'key']
df = pd.merge(df, df2, on='key')

df['favored text'] = df.apply(lambda x: x['text'] if x['count'] > x['count2'] else x['text2'], axis=1)
df['negative text'] = df.apply(lambda x: x['text'] if x['count'] < x['count2'] else x['text2'], axis=1)

df = df[['favored text', 'negative text']].drop_duplicates()
df
# Out:
#                                           favored text  \
# 0    Ely grater:\nI have thall grown to shalm caul ...
# 1    I'll deast in Romeence\nTo men that decede pro...
# 2    Go your fain take shuld for ove provess than l...
# 3    Ely grater:\nI have thall grown to shalm caul ...
# 4    Ely grater:\nI have thall grown to shalm caul ...
# ..                                                 ...
# 193  Dece to the pligo; I'll my pray, ganters.\n\nI...
# 194  Foll for death with dand fright your cans-to h...
# 208  Dece to the pligo; I'll my pray, ganters.\n\nI...
# 209  Foll for death with dand fright your cans-to h...
# 224  Foll for death with dand fright your cans-to h...
#
#                                          negative text
# 0    Ely grater:\nI have thall grown to shalm caul ...
# 1    I'll deast in Romeence\nTo men that decede pro...
# 2    Ely grater:\nI have thall grown to shalm caul ...
# 3    RAUS:\nHet a dought the wome, in behis coman a...
# 4    him not be proted for all wremal the aged of l...
# ..                                                 ...
# 193  That one componters so arce that to spares the...
# 194  That one componters so arce that to spares the...
# 208  Dece to the pligo; I'll my pray, ganters.\n\nI...
# 209  Dece to the pligo; I'll my pray, ganters.\n\nI...
# 224  Foll for death with dand fright your cans-to h...
#
# [108 rows x 2 columns]

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torch import nn, optim

# Define character-to-index mapping
char_to_idx = {ch: idx for idx, ch in enumerate("abcdefghijklmnopqrstuvwxyz ")}
idx_to_char = {idx: ch for ch, idx in char_to_idx.items()}
vocab_size = len(char_to_idx)
max_length = 500  # Define max sequence length

# Function to encode text as character indices
def encode_text(text, char_to_idx, max_length):
    indices = [char_to_idx.get(char, 0) for char in text.lower()[:max_length]]
    return indices + [0] * (max_length - len(indices))

# decode text
def decode_text(indices, idx_to_char):
    text = ''.join([idx_to_char[idx] for idx in indices])
    return text

# Custom Dataset
class RewardDataset(Dataset):
    def __init__(self, dataframe, char_to_idx, max_length):
        self.data = dataframe
        self.char_to_idx = char_to_idx
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        favored_text = self.data.iloc[idx]['favored text']
        negative_text = self.data.iloc[idx]['negative text']
        
        # Encode the texts
        favored_encoded = torch.tensor(encode_text(favored_text, self.char_to_idx, self.max_length))
        negative_encoded = torch.tensor(encode_text(negative_text, self.char_to_idx, self.max_length))
        
        return favored_encoded, negative_encoded, torch.tensor(1.0), torch.tensor(0.0)

# Define a simple character-based reward model
class CharRewardModel(nn.Module):
    def __init__(self, vocab_size, embed_dim=32):
        super(CharRewardModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, 64, batch_first=True)
        self.fc = nn.Linear(64, 1)

    def forward(self, x):
        embedded = self.embedding(x)
        _, (hidden, _) = self.lstm(embedded)  # hidden: [1, batch_size, 64]
        output = self.fc(hidden)
        return output.squeeze(0).squeeze(1)

# Instantiate the dataset and model
dataset = RewardDataset(dataframe=df, char_to_idx=char_to_idx, max_length=max_length)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)
model = CharRewardModel(vocab_size=vocab_size)

# Training setup
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-3)

# Training loop
for epoch in range(7):
    for batch in dataloader:
        favored_text, negative_text, favored_label, negative_label = batch

        # Forward pass
        favored_reward = model(favored_text)
        negative_reward = model(negative_text)

        # Calculate loss
        loss_favored = criterion(favored_reward, favored_label)
        loss_negative = criterion(negative_reward, negative_label)
        loss = (loss_favored + loss_negative) / 2

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(f"Epoch {epoch + 1}, Loss: {loss.item()}")
# Out:
# Epoch 1, Loss: 0.6277613043785095
# Epoch 2, Loss: 0.48914700746536255
# Epoch 3, Loss: 0.396189421415329
# Epoch 4, Loss: 0.5505608320236206
# Epoch 5, Loss: 0.3692547082901001
# Epoch 6, Loss: 0.4334373474121094
# Epoch 7, Loss: 0.5982861518859863

# %%
df_eval = df_eval.rename(columns={'text': 'favored text', 'count': 'favored count'})
df_eval['negative text'] = ''

# %%
# eval
eval_dataset = RewardDataset(dataframe=df_eval, char_to_idx=char_to_idx, max_length=max_length)
eval_dataloader = DataLoader(eval_dataset, batch_size=1)

for batch in eval_dataloader:
    favored_text, negative_text, favored_label, negative_label = batch
    reward = model(favored_text)
    decoded_text = decode_text(favored_text[0].numpy(), idx_to_char)
    print(f"Reward: {reward.item()}, Label: {favored_label.item()}")
    print("Favored text:")
    print(decoded_text)
    print("\n")
# Out:
# Reward: 0.7995948195457458, Label: 1.0
# Favored text:
# aking etesaasira the not must mut here the him gooda and thy deathaaand pan a with and twicked on enteriesaaof your daess his mines all look bood i do a haveaathan from in of leent prove to heave andermanceato my loop that not most he way causa a poweraaavoleoaathat proviong i dighce affforeras be eve such willathat not in the purs proved need didiedsaathe me farl out my will with and his vill and our wallaadet the sigh lecousid the parkad thoughta i to that stansaaamucopsioaawels muta what youa
#
#
# Reward: 0.5747926235198975, Label: 1.0
# Favored text:
# then good a forsing it have fouls that hereaawhe lorgom the the gall thana she long i what thatathing agguntaour thing levidy i with how curse pleasa you sheaveaaher he gooda she crow on know live some so coudsesleaaduke to me in lie the of the dought thy his the heave my theeaaand sperfery that wite from to that comfur fort sheathy the here he rid he some of you cious areaaabut sickinghard iiiaawell a doth of the tervengead have her notaaaaufctiliaaaa not prusta and tell likea and her not browa
#
#
# Reward: 0.22016699612140656, Label: 1.0
# Favored text:
# and precomed me uny lop youaai i we how thee will ove boy not stry grown all notaa be ligaato have somel tendaaaking edwardaathing gromea goodas a it en thee this king thoumaaastomeaafiraalet no too the i know itstand murse the part thou offenathing tieaathe the heave come me it thous are the reppinceaathou forth slandreed stlee in this witeaain ving one soa stand and of the blagea my the can to willaada andafor her aaaleonvaaai ara i a sought entat no daya who dies from the howain preoud are up
#
#
# Reward: 1.228036642074585, Label: 1.0
# Favored text:
# shoble boterad sire to death nowa and sull pleaceaai in steentas shaulcan of you faly greace highasighurnot cord the may we his say fach thanesaa stand in greath all your have out soun but youraand the kingly mada andaaamariniusaahe dow hatha i come his seeaaagloucessteraayou hears deathousa beam so sunteraaaduke vintingbraasauling thes aons he plaactinsa good i partyaarever ampout as a dup the earsonabears the speartior a thou will hight to pead of the the wouldaough woult be sont the now hear
#
#
# Reward: -0.7433869242668152, Label: 1.0
# Favored text:
# engue to my sidirst hea will be thee it the not hat thoughaasaof to sarries a to apray i can lam to and will vearingaa what more noble of your detiled and onathe dike of murse your not worlas shall how sheeamy own a a loughts to argea i bring enveryaahe are couse man my age his good hope thisaaand be live in to king and the folf freathseaathen the sonea wid sing courst bent my me stretaathena to yet my that teive rough in lowdaacititer the gack haftle to carde give the fortaaare prienta i ever i

# %% [markdown]
# # RLHF

# %%
# additional layer based on text output and reward
# define a policy model

class PolicyRNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(PolicyRNN, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden=None):
        embedded = self.embedding(x)
        out, hidden = self.rnn(embedded, hidden)
        logits = self.fc(out)
        return logits, hidden

    def sample(self, seed, max_length):
        "Generates text sequence up to max_len tokens"
        generated_text = generate_text(seed)
        input_token = torch.tensor(encode_text(generated_text, char_to_idx, max_length))
        return generated_text, input_token


# reward function
def reward_function(text, model):
    encoded_text = torch.tensor(encode_text(text, char_to_idx, max_length)).unsqueeze(0)
    return model(encoded_text).item()

# loss function
def policy_loss(logits, actions, rewards):
    log_probs = torch.log_softmax(logits, dim=-1)
    actions = actions.unsqueeze(-1)
    action_log_probs = log_probs.gather(2, actions)
    return -(action_log_probs * rewards).mean()

# Instantiate the policy model
policy_model = PolicyRNN(vocab_size=vocab_size, embedding_dim=32, hidden_dim=64)
optimizer = optim.AdamW(policy_model.parameters(), lr=1e-3)

# Training loop
for epoch in range(5):
    seed = epoch
    max_length = 500
    generated_text, input_token = policy_model.sample(seed, max_length)
    sequence_tensor = torch.tensor(input_token).unsqueeze(0)
    
    # reward
    reward = reward_function(generated_text, model) # Use the reward model to calculate the reward
    reward_tensor = torch.tensor(reward).repeat(sequence_tensor.size(1))
    
    # Forward pass
    logits, _ = policy_model(sequence_tensor)
    
    # Calculate loss
    loss = policy_loss(logits, sequence_tensor, reward_tensor)
    
    # Backward pass and optimization
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    print(f"Epoch {epoch + 1}, Loss: {loss.item()}")
# Out:
# C:\Users\Zheng\AppData\Local\Temp\ipykernel_36232\1034675975.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   sequence_tensor = torch.tensor(input_token).unsqueeze(0)
# Epoch 1, Loss: 2.0523293018341064
# Epoch 2, Loss: 2.088833808898926
# Epoch 3, Loss: -2.4265503883361816
# Epoch 4, Loss: 2.6110448837280273
# Epoch 5, Loss: 7.018655776977539

# %%
# check
seed = 1029
max_length = 500
generated_text, input_token = policy_model.sample(seed, max_length)
# use model
results = policy_model(input_token)
results = results[0].argmax(dim=-1).numpy()
decoded_text = decode_text(results, idx_to_char)
print(decoded_text)
# Out:
# ...
